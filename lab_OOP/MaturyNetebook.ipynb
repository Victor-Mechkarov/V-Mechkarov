# %%
import pandas as pd

# %%
def compared(dictionary: dict, keyword: str):
    for k, v in dictionary.items():
        if k.startswith(keyword):
            print(f"{k} : {v}")

def results(dict1:dict,dict2:dict):
    for (k1, v1), (k2, v2) in zip(dict1.items(), dict2.items()): 
        if k1 in dict2.keys() and v2>= v1:
            print(f"{k2} : {v2} : {v1}")
    


df = pd.read_excel("ujass.xlsx")

X = df.to_numpy()

rows_list = []
values = []

for row in X:
    rows = ([row[3], row[2], row[4]])
    rows = (' '.join(str(row) for row in rows))
    rows_list.append(rows)
    value = row[5]
    values.append(value)

dictionary_2025 = dict(zip(rows_list, values))

df = pd.read_excel("edited.xlsx")
#df = pd.read_excel("ed_27.xlsx")
data_dict = df.to_numpy()
mapper_data = {}
index_1 = []
index_2 = []
index_3 = []
index_4 = []
for el in data_dict:
    mapper_data[el[1], el[2], el[3]] = el[4]
    index_1.append(el[1])
    index_2.append(el[2])
    index_3.append(el[3])
    index_4.append(el[4])

df_1 = pd.read_excel("ball.xlsx")
data_dict_1 = df_1.to_numpy()
mapper_data_2 = {}
element_1 = []
info_list = []
element_4 = []
mapper_data_dict_1 = {}

for y in data_dict_1:
    mapper_data_2[y[0], y[1], y[3]] = y[4:]
    element_1.append(y[1])
    info_list.append(y[2])
    element_4.append(y[4])

string_w = dict(zip(index_2, index_4))
stright_y = dict(zip(element_1, element_4))

A = sorted(string_w.items(), key=lambda x: x[0])
B = sorted(stright_y.items(), key=lambda x: x[0])

concatenated_mapper = {}
for y in data_dict:
    concatenated_mapper[str(y[2]) + " " + y[1] + " " + y[3]] = y[4]

concatenated_mapper_2 = {}
for z in data_dict_1:
    concatenated_mapper_2[str(z[1]) + " " + z[0] + " " + z[2]] = z[4]


while True:
    try:
        convertor = {6: 50, 5: 39, 4: 26, 3: 15, 2: 0}

        print("Въведи оценките от дипломата!")

        math = int(input("Математика :"))
        bel = int(input("БЕЛ :"))
        phz = int(input("Физика :"))
        ic = int(input("История :"))
        kt = int(input("Ком. моделиране и ИТ :"))
        fl = int(input("Чужд език :"))
        music = int(input("Музика :"))
        ii = int(input("Изобразително искуство :"))
        bio = int(input("Биология :"))
        geo = int(input("География :"))
        fv = int(input("Физическо възпитание :"))
        chem = int(input("Химия :"))
        tp = int(input("Технологии и предприемчество :"))

        if (
            math in convertor.keys()
            and bel in convertor.keys()
            and phz in convertor.keys()
            and ic in convertor.keys()
            and kt in convertor.keys()
            and fl in convertor.keys()
            and bio in convertor.keys()
            and geo in convertor.keys()
            and fv in convertor.keys()
            and chem in convertor.keys()
            and tp in convertor.keys()
        ):
            math_points = convertor[math]
            bel_points = convertor[bel]
            phz_points = convertor[phz]
            ic_points = convertor[ic]
            kt_points = convertor[kt]
            fl_points = convertor[fl]
            music_points = convertor[music]
            bio_points = convertor[bio]
            geo_points = convertor[geo]
            fv_points = convertor[fv]
            chem_points = convertor[chem]
            tp_points = convertor[tp]
            ii_points = convertor[ii]

            break

    except (KeyError, ValueError):
        print("Въведи цяло число от 2 до 6!")

while True:
    try:
        print()

        special_exams = False

        math_exam = float(input("Въведи оценка от НВО - Математика:  "))
        bel_exam = float(input("Въвди оценка от НВО - БЕЛ:  "))
        specials_array = {
            "music_exam": 1.0,
            "ii_exam": 1.0,
            "fv_exam": 1.0,
            "bio_exam": 1.0,
            "chem_exam": 1.0,
            "phz_exam": 1.0,
            "geo_exam": 1.0,
        }
        print(
            "Ако кандидатствате за профилирана гимназия с доп. НВО изберте '1' ако не '0"
        )

        additional = int(input("Въведи:  "))

        if additional == 1:
            special_exams = True
            while True:
                try:
                    specials_array = {
                        "music_exam": 1.0,
                        "ii_exam": 1.0,
                        "fv_exam": 1.0,
                        "bio_exam": 1.0,
                        "chem_exam": 1.0,
                        "phz_exam": 1.0,
                        "geo_exam": 1.0,
                    }
                    flag = False
                    for _ in range(int(input("Въведи брой на доп. НВО:   "))):
                        nvo_1 = input(
                            "Въведи music_exam, ii_exam, fv_exam, bio_exam, chem_exam, phz_exam:"
                        )
                        special_nvo = float(input("Въведи оценка от НВО (0 - 100):   "))
                        if nvo_1 in specials_array.keys() and special_nvo <= 100:
                            specials_array[nvo_1] = special_nvo
                            flag = True
                    if flag:
                        break
                except (KeyError, ValueError, IndexError):
                    print("Въведете валидни данни")

        if 0 < math_exam <= 100 and 0 < bel_exam <= 100:
            break

    except (
        IndexError,
        ValueError,
    ):
        print("Въведи влидни данни - от 0 до 100")

print(math_exam)
print(bel_exam)

if special_exams:
    for key, value in specials_array.items():
        if value > 0:
            print(f"{key}: {value}")

mapper_convertor = {
    "(3 * БЕЛ + 1 * МАТ) + (1 * ФВС + 1 * ЧЕз)": 3 * bel_exam
    + math_exam
    + fv_points
    + fl_points,
    "(1 * БЕЛ + 1 * МАТ + 2 * ИИ) + (1 * ИИ + 1 * КМИТ)": bel_exam
    + math_exam
    + 2 * specials_array["ii_exam"]
    + ii_points
    + kt_points,
    "(3 * БЕЛ + 1 * МАТ) + (1 * ИЦ + 1 * ГИ)": 2 * bel_exam
    + 2 * math_exam
    + bel_points
    + geo_points,
    "(2 * БЕЛ + 2 * МАТ) + (1 * БЕЛ + 1 * ГИ)": 2 * bel_exam
    + 2 * math_exam
    + bel_points
    + geo_points,
    "(2 * БЕЛ + 2 * МАТ) + (1 * ГИ + 1 * КМИТ)": 2 * bel_exam
    + 2 * math_exam
    + geo_points
    + kt_points,
    "(3 * БЕЛ + 1 * МАТ) + (1 * БЗО + 1 * ХООС)": 3 * bel_exam
    + math_exam
    + bio_points
    + chem_points,
    "(1 * БЕЛ + 3 * МАТ) + (1 * БЕЛ + 1 * М)": 3 * math_exam
    + bel_exam
    + bel_points
    + math_points,
    "(3 * БЕЛ + 1 * МАТ) + (1 * КМИТ + 1 * ЧЕз)": 3 * bel_exam
    + math_exam
    + kt_points
    + fl_points,
    "(3 * БЕЛ + 1 * МАТ) + (1 * ИЦ + 1 * Муз.)": 3 * bel_exam
    + math_exam
    + ic_points
    + music_points,
    "(1 * БЕЛ + 1 * МАТ + 2 * МУЗ) + (1 * БЕЛ + 1 * Муз.)": bel_exam
    + math_exam
    + 2 * specials_array["music_exam"]
    + bel_points
    + music_points,
    "(2 * БЕЛ + 2 * МАТ) + (1 * ГИ + 1 * БЗО)": 2 * bel_exam
    + 2 * math_exam
    + geo_points
    + bio_points,
    "(1 * БЕЛ + 2 * МАТ + 1 * НПМГ, Ф) + (1 * М + 1 * ФА) или (1 * БЕЛ + 2 * МАТ + 1 * ФИЗ, ОК) + (1 * М + 1 * ФА)": bel_exam
    + 2 * math_exam
    + specials_array["phz_exam"]
    + math_points
    + phz_points,
    "(1 * БЕЛ + 3 * МАТ) + (1 * БЗО + 1 * ХООС)": bel_exam
    + 3 * math_exam
    + bio_points
    + chem_points,
    "(1 * БЕЛ + 1 * МАТ + 2 * БИО, ОК) + (1 * БЗО + 1 * ХООС) или (1 * БЕЛ + 1 * МАТ + 2 * НПМГ, Б) + (1 * БЗО + 1 * ХООС)": bel_exam
    + math_exam
    + 2 * specials_array["bio_exam"]
    + bio_points
    + chem_points,
    "(2 * БЕЛ + 2 * МАТ) + (1 * БЕЛ + 1 * КМИТ)": 2 * bel_exam
    + 2 * math_exam
    + bel_points
    + kt_points,
    "(3 * БЕЛ + 1 * МАТ) + (1 * ИЦ + 1 * КМИТ)": 3 * bel_exam
    + math_exam
    + ic_points
    + kt_points,
    "(3 * БЕЛ + 1 * МАТ) + (1 * ГИ + 1 * ТП)": 3 * bel_exam
    + math_exam
    + geo_points
    + tp_points,
    "(3 * БЕЛ + 1 * МАТ) + (1 * ИИ + 1 * КМИТ)": 3 * bel_exam
    + math_exam
    + bio_points
    + chem_points,
    "(3 * БЕЛ + 1 * МАТ) + (1 * ИЦ + 1 * ЧЕз)": 3 * bel_exam
    + math_exam
    + ic_points
    + fl_points,
    "(3 * БЕЛ + 1 * МАТ) + (1 * ГИ + 1 * ЧЕз)": 3 * bel_exam
    + math_exam
    + geo_points
    + fl_points,
    "(3 * БЕЛ + 1 * МАТ) + (1 * БЕЛ + 1 * М)": 3 * bel_exam
    + math_exam
    + bel_points
    + math_points,
    "(2 * БЕЛ + 2 * МАТ) + (1 * ИИ + 1 * ТП)": 2 * bel_exam
    + 2 * math_exam
    + ii_points
    + tp_points,
    "(3 * БЕЛ + 1 * МАТ) + (1 * БЗО + 1 * ЧЕз)": 3 * bel_exam
    + math_exam
    + bio_points
    + fl_points,
    "(2 * БЕЛ + 2 * МАТ) + (1 * ИЦ + 1 * ГИ)": 2 * bel_exam
    + 2 * math_exam
    + ic_points
    + geo_points,
    "(3 * БЕЛ + 1 * МАТ) + (1 * БЕЛ + 1 * КМИТ)": 3 * bel_exam
    + math_exam
    + bel_points
    + kt_points,
    "(3 * БЕЛ + 1 * МАТ) + (1 * ГИ + 1 * КМИТ)": 3 * bel_exam
    + math_exam
    + geo_points
    + kt_points,
    "(2 * БЕЛ + 2 * МАТ) + (1 * БЕЛ + 1 * БЗО)": 2 * bel_exam
    + 2 * math_exam
    + bel_points
    + bio_points,
    "(2 * БЕЛ + 2 * МАТ) + (1 * ГИ + 1 * ЧЕз)": 2 * bel_exam
    + 2 * math_exam
    + geo_points
    + fl_points,
    "(1 * БЕЛ + 2 * МАТ + 1 * ХИМ, ОК) + (1 * БЗО + 1 * ХООС) или (1 * БЕЛ + 2 * МАТ + 1 * НПМГ, Х) + (1 * БЗО + 1 * ХООС)": bel_exam
    + 2 * math_exam
    + specials_array["chem_exam"]
    + bio_points
    + chem_points,
    "(1 * БЕЛ + 3 * МАТ) + (1 * БЕЛ + 1 * ГИ)": bel_exam
    + 2 * math_exam
    + bel_points
    + geo_points,
    "(2 * БЕЛ + 2 * МАТ) + (1 * М + 1 * ГИ)": 2 * bel_exam
    + 2 * math_exam
    + math_points
    + geo_points,
    "(1 * БЕЛ + 1 * МАТ + 2 * СПО) + (1 * БЗО + 1 * ЧЕз)": bel_exam
    + math_exam
    + 2 * specials_array["fv_exam"]
    + bio_points
    + fl_points,
    "(2 * БЕЛ + 2 * МАТ) + (1 * ИИ + 1 * КМИТ)": 2 * bel_exam
    + 2 * math_exam
    + ii_points
    + kt_points,
    "(2 * БЕЛ + 2 * МАТ) + (1 * БЗО + 1 * ХООС)": 2 * bel_exam
    + 2 * math_exam
    + bio_points
    + chem_points,
    "(2 * БЕЛ + 2 * МАТ) + (1 * БЕЛ + 1 * ЧЕз)": 2 * bel_exam
    + 2 * math_exam
    + bio_points
    + chem_points,
    "(3 * БЕЛ + 1 * МАТ) + (1 * БЕЛ + 1 * БЗО)": 3 * bel_exam
    + math_exam
    + bel_points
    + bio_points,
    "(1 * БЕЛ + 1 * МАТ + 2 * СПО) + (1 * БЗО + 1 * ФВС)": bel_exam
    + math_exam
    + 2 * specials_array["fv_exam"]
    + bio_points
    + fv_points,
    "(1 * БЕЛ + 1 * МАТ + 2 * ИИ) + (1 * БЕЛ + 1 * ИИ)": bel_exam
    + math_exam
    + 2 * specials_array["ii_exam"]
    + bel_points
    + ii_points,
    "(2 * БЕЛ + 2 * МАТ) + (1 * ГИ + 1 * ТП)": 2 * bel_exam
    + 2 * math_exam
    + geo_points
    + tp_points,
    "(3 * БЕЛ + 1 * МАТ) + (1 * БЕЛ + 1 * ИЦ)": 3 * bel_exam
    + math_exam
    + bel_points
    + ic_points,
    "(2 * БЕЛ + 2 * МАТ) + (1 * ФА + 1 * БЗО)": 2 * bel_exam
    + 2 * math_exam
    + phz_points
    + bio_points,
    "(2 * БЕЛ + 2 * МАТ) + (1 * БЗО + 1 * ЧЕз)": 2 * bel_exam
    + 2 * math_exam
    + bio_points
    + fl_points,
    "(2 * БЕЛ + 2 * МАТ) + (1 * БЕЛ + 1 * ИИ)": 2 * bel_exam
    + 2 * math_exam
    + bel_points
    + ii_points,
    "(3 * БЕЛ + 1 * МАТ) + (1 * БЕЛ + 1 * ИИ)": 3 * bel_exam
    + math_exam
    + bel_points
    + ii_points,
    "(1 * БЕЛ + 1 * МАТ + 2 * ИИ) + (1 * ИИ + 1 * ЧЕз)": bel_exam
    + math_exam
    + 2 * specials_array["ii_exam"]
    + ii_points
    + fl_points,
    "(3 * БЕЛ + 1 * МАТ) + (1 * БЕЛ + 1 * ГИ)": 3 * bel_exam
    + math_exam
    + bel_points
    + geo_points,
    "(2 * БЕЛ + 2 * МАТ) + (1 * М + 1 * КМИТ)": 2 * bel_exam
    + 2 * math_exam
    + math_points
    + kt_points,
    "(1 * БЕЛ + 3 * МАТ) + (1 * М + 1 * ФА)": bel_exam
    + 3 * math_exam
    + math_points
    + phz_points,
    "(1 * БЕЛ + 3 * МАТ) + (1 * БЗО + 1 * ИИ)": bel_exam
    + 3 * math_exam
    + bio_points
    + ii_points,
    "(1 * БЕЛ + 3 * МАТ) + (1 * ФА + 1 * ИИ)": bel_exam
    + 3 * math_exam
    + phz_points
    + ii_points,
    "(2 * БЕЛ + 2 * МАТ) + (1 * КМИТ + 1 * ЧЕз)": 2 * bel_exam
    + 2 * math_exam
    + kt_points
    + fl_points,
    "(3 * БЕЛ + 1 * МАТ) + (1 * БЕЛ + 1 * ФВС)": 3 * bel_exam
    + math_exam
    + bel_points
    + fv_points,
    "(2 * БЕЛ + 2 * МАТ) + (1 * БЕЛ + 1 * ИЦ)": 2 * bel_exam
    + 2 * math_exam
    + bel_points
    + ic_points,
    "(2 * БЕЛ + 2 * МАТ) + (1 * КМИТ + 1 * ТП)": 2 * bel_exam
    + 2 * math_exam
    + kt_points
    + tp_points,
    "(1 * БЕЛ + 3 * МАТ) + (1 * М + 1 * КМИТ)": bel_exam
    + 3 * math_exam
    + math_points
    + kt_points,
    "(2 * БЕЛ + 2 * МАТ) + (1 * М + 1 * ФА)": 2 * bel_exam
    + 2 * math_exam
    + math_points
    + phz_points,
    "(3 * БЕЛ + 1 * МАТ) + (1 * БЗО + 1 * ИИ)": 3 * bel_exam
    + math_exam
    + bio_points
    + ii_points,
    "(1 * БЕЛ + 1 * МАТ + 1 * НПМГ, Х + 1 * НПМГ, Б) + (1 * БЗО + 1 * ХООС)": bel_exam
    + math_exam
    + specials_array["chem_exam"]
    + specials_array["bio_exam"]
    + bio_points
    + chem_points,
    "(3 * БЕЛ + 1 * МАТ) + (1 * БЕЛ + 1 * ЧЕз)": 3 * bel_exam
    + 1 * math_exam
    + math_points
    + fl_points,
    "(2 * БЕЛ + 2 * МАТ) + (1 * М + 1 * ЧЕз)": 2 * bel_exam
    + 2 * math_exam
    + bio_points
    + math_points,
    "(2 * БЕЛ + 2 * МАТ) + (1 * БЕЛ + 1 * М)": 2 * bel_exam
    + 2 * math_exam
    + bel_points
    + math_points,
    "(1 * БЕЛ + 2 * МАТ + 1 * ГЕО, ОК) + (1 * М + 1 * ГИ) или (1 * БЕЛ + 2 * МАТ + 1 * НПМГ, Г) + (1 * М + 1 * ГИ)": bel_exam
    + 2 * math_exam
    + specials_array["geo_exam"]
    + math_points
    + geo_points,
    "(2 * БЕЛ + 2 * МАТ) + (1 * ФА + 1 * КМИТ)": 2 * bel_exam
    + 2 * math_exam
    + phz_points
    + kt_points,
    "(1 * БЕЛ + 1 * МАТ + 2 * МиФВС) + (1 * БЕЛ + 1 * Муз.)": bel_exam
    + math_exam
    + 2 * specials_array["fv_exam"]
    + bel_points
    + music_points,
}
print()
print(
    "Списък с постигнатият бал, на база оценките"
    "\n"
    "от дипломата и резултата от НВО, в зависимост"
    "\n"
    "от всички възможни комбинации за балообразуване."
    "\n"
    "Данните са сортирани по низхдящ ред (Наи-висок -> Наи-нисък)"
)
print()
for result in sorted(mapper_convertor.items(), key=lambda kvp: round(-kvp[1], 2)):
    print(f"{result[0]:<80} : {result[1]:>4.2f}")
print()
print(
    f"Резултати от минималните балове за класиране по училища:"
    "\n"
    "за предходна година."
)
print()
las_score = []
for k, v in dictionary_2025.items():
    las_score.append(v)
    print(f"{k:<120} : {v:>7.2f}")
print()
print()
final_mapper = {}
for key, value in concatenated_mapper_2.items():
    if value in mapper_convertor.keys():
        value = mapper_convertor[value]
        final_mapper[key] = value

print()
print(f"Сортирани резултати от най-високият по училища.")
print()
for element in sorted(final_mapper.items(), key=lambda kvp: -kvp[1]):
    print(f"{element[0]:<130}:{element[1]:>7.2f}")
print()
print()
print(
    "Въвеждане на код за сравнвние на постигнатия бал на учника"
    "\n"
    "с минималнит бал за прием от предходната година. Изберете кода"
    "\n"
    "пред името на училището от списъка по-горе. Въведи ЕND за край!"
)
print()
while True:
    print()
    code = input("CODE / END:   "
    )
    if code == "END":
        break
    print()
    print("Вашият резултат:")
    compared(final_mapper, code)
    print()
    print("Минимален бал от предходха година:")
    compared(dictionary_2025, code)
print()
print()

#results(dictionary_2025, final_mapper)
# Out:
# Въведи оценките от дипломата!
# Математика : 5
# БЕЛ : 5
# Физика : 6
# История : 4
# Ком. моделиране и ИТ : 5
# Чужд език : 5
# Музика : 5
# Изобразително искуство : 6
# Биология : 5
# География : 4
# Физическо възпитание : 6
# Химия : 5
# Технологии и предприемчество : 4
# Въведи оценка от НВО - Математика:   55.75
# Въвди оценка от НВО - БЕЛ:   61
# Ако кандидатствате за профилирана гимназия с доп. НВО изберте '1' ако не '0
# Въведи:   0
# 55.75
# 61.0
#
# Списък с постигнатият бал, на база оценките
# от дипломата и резултата от НВО, в зависимост
# от всички възможни комбинации за балообразуване.
# Данните са сортирани по низхдящ ред (Наи-висок -> Наи-нисък)
#
# (1 * БЕЛ + 3 * МАТ) + (1 * ФА + 1 * ИИ)                                          : 328.25
# (3 * БЕЛ + 1 * МАТ) + (1 * ФВС + 1 * ЧЕз)                                        : 327.75
# (3 * БЕЛ + 1 * МАТ) + (1 * БЕЛ + 1 * ИИ)                                         : 327.75
# (3 * БЕЛ + 1 * МАТ) + (1 * БЕЛ + 1 * ФВС)                                        : 327.75
# (3 * БЕЛ + 1 * МАТ) + (1 * БЗО + 1 * ИИ)                                         : 327.75
# (2 * БЕЛ + 2 * МАТ) + (1 * ИИ + 1 * КМИТ)                                        : 322.50
# (2 * БЕЛ + 2 * МАТ) + (1 * ФА + 1 * БЗО)                                         : 322.50
# (2 * БЕЛ + 2 * МАТ) + (1 * БЕЛ + 1 * ИИ)                                         : 322.50
# (2 * БЕЛ + 2 * МАТ) + (1 * М + 1 * ФА)                                           : 322.50
# (2 * БЕЛ + 2 * МАТ) + (1 * ФА + 1 * КМИТ)                                        : 322.50
# (1 * БЕЛ + 3 * МАТ) + (1 * М + 1 * ФА)                                           : 317.25
# (1 * БЕЛ + 3 * МАТ) + (1 * БЗО + 1 * ИИ)                                         : 317.25
# (3 * БЕЛ + 1 * МАТ) + (1 * БЗО + 1 * ХООС)                                       : 316.75
# (3 * БЕЛ + 1 * МАТ) + (1 * КМИТ + 1 * ЧЕз)                                       : 316.75
# (3 * БЕЛ + 1 * МАТ) + (1 * ИИ + 1 * КМИТ)                                        : 316.75
# (3 * БЕЛ + 1 * МАТ) + (1 * БЕЛ + 1 * М)                                          : 316.75
# (3 * БЕЛ + 1 * МАТ) + (1 * БЗО + 1 * ЧЕз)                                        : 316.75
# (3 * БЕЛ + 1 * МАТ) + (1 * БЕЛ + 1 * КМИТ)                                       : 316.75
# (3 * БЕЛ + 1 * МАТ) + (1 * БЕЛ + 1 * БЗО)                                        : 316.75
# (3 * БЕЛ + 1 * МАТ) + (1 * БЕЛ + 1 * ЧЕз)                                        : 316.75
# (2 * БЕЛ + 2 * МАТ) + (1 * БЕЛ + 1 * КМИТ)                                       : 311.50
# (2 * БЕЛ + 2 * МАТ) + (1 * БЕЛ + 1 * БЗО)                                        : 311.50
# (2 * БЕЛ + 2 * МАТ) + (1 * БЗО + 1 * ХООС)                                       : 311.50
# (2 * БЕЛ + 2 * МАТ) + (1 * БЕЛ + 1 * ЧЕз)                                        : 311.50
# (2 * БЕЛ + 2 * МАТ) + (1 * БЗО + 1 * ЧЕз)                                        : 311.50
# (2 * БЕЛ + 2 * МАТ) + (1 * М + 1 * КМИТ)                                         : 311.50
# (2 * БЕЛ + 2 * МАТ) + (1 * КМИТ + 1 * ЧЕз)                                       : 311.50
# (2 * БЕЛ + 2 * МАТ) + (1 * М + 1 * ЧЕз)                                          : 311.50
# (2 * БЕЛ + 2 * МАТ) + (1 * БЕЛ + 1 * М)                                          : 311.50
# (2 * БЕЛ + 2 * МАТ) + (1 * ИИ + 1 * ТП)                                          : 309.50
# (1 * БЕЛ + 3 * МАТ) + (1 * БЕЛ + 1 * М)                                          : 306.25
# (1 * БЕЛ + 3 * МАТ) + (1 * БЗО + 1 * ХООС)                                       : 306.25
# (1 * БЕЛ + 3 * МАТ) + (1 * М + 1 * КМИТ)                                         : 306.25
# (3 * БЕЛ + 1 * МАТ) + (1 * ИЦ + 1 * Муз.)                                        : 303.75
# (3 * БЕЛ + 1 * МАТ) + (1 * ИЦ + 1 * КМИТ)                                        : 303.75
# (3 * БЕЛ + 1 * МАТ) + (1 * ИЦ + 1 * ЧЕз)                                         : 303.75
# (3 * БЕЛ + 1 * МАТ) + (1 * ГИ + 1 * ЧЕз)                                         : 303.75
# (3 * БЕЛ + 1 * МАТ) + (1 * ГИ + 1 * КМИТ)                                        : 303.75
# (3 * БЕЛ + 1 * МАТ) + (1 * БЕЛ + 1 * ИЦ)                                         : 303.75
# (3 * БЕЛ + 1 * МАТ) + (1 * БЕЛ + 1 * ГИ)                                         : 303.75
# (3 * БЕЛ + 1 * МАТ) + (1 * ИЦ + 1 * ГИ)                                          : 298.50
# (2 * БЕЛ + 2 * МАТ) + (1 * БЕЛ + 1 * ГИ)                                         : 298.50
# (2 * БЕЛ + 2 * МАТ) + (1 * ГИ + 1 * КМИТ)                                        : 298.50
# (2 * БЕЛ + 2 * МАТ) + (1 * ГИ + 1 * БЗО)                                         : 298.50
# (2 * БЕЛ + 2 * МАТ) + (1 * ГИ + 1 * ЧЕз)                                         : 298.50
# (2 * БЕЛ + 2 * МАТ) + (1 * М + 1 * ГИ)                                           : 298.50
# (2 * БЕЛ + 2 * МАТ) + (1 * БЕЛ + 1 * ИЦ)                                         : 298.50
# (2 * БЕЛ + 2 * МАТ) + (1 * КМИТ + 1 * ТП)                                        : 298.50
# (3 * БЕЛ + 1 * МАТ) + (1 * ГИ + 1 * ТП)                                          : 290.75
# (2 * БЕЛ + 2 * МАТ) + (1 * ИЦ + 1 * ГИ)                                          : 285.50
# (2 * БЕЛ + 2 * МАТ) + (1 * ГИ + 1 * ТП)                                          : 285.50
# (1 * БЕЛ + 2 * МАТ + 1 * НПМГ, Ф) + (1 * М + 1 * ФА) или (1 * БЕЛ + 2 * МАТ + 1 * ФИЗ, ОК) + (1 * М + 1 * ФА) : 262.50
# (1 * БЕЛ + 2 * МАТ + 1 * ХИМ, ОК) + (1 * БЗО + 1 * ХООС) или (1 * БЕЛ + 2 * МАТ + 1 * НПМГ, Х) + (1 * БЗО + 1 * ХООС) : 251.50
# (1 * БЕЛ + 2 * МАТ + 1 * ГЕО, ОК) + (1 * М + 1 * ГИ) или (1 * БЕЛ + 2 * МАТ + 1 * НПМГ, Г) + (1 * М + 1 * ГИ) : 238.50
# (1 * БЕЛ + 3 * МАТ) + (1 * БЕЛ + 1 * ГИ)                                         : 237.50
# (1 * БЕЛ + 1 * МАТ + 2 * ИИ) + (1 * ИИ + 1 * КМИТ)                               : 207.75
# (1 * БЕЛ + 1 * МАТ + 2 * СПО) + (1 * БЗО + 1 * ФВС)                              : 207.75
# (1 * БЕЛ + 1 * МАТ + 2 * ИИ) + (1 * БЕЛ + 1 * ИИ)                                : 207.75
# (1 * БЕЛ + 1 * МАТ + 2 * ИИ) + (1 * ИИ + 1 * ЧЕз)                                : 207.75
# (1 * БЕЛ + 1 * МАТ + 2 * МУЗ) + (1 * БЕЛ + 1 * Муз.)                             : 196.75
# (1 * БЕЛ + 1 * МАТ + 2 * БИО, ОК) + (1 * БЗО + 1 * ХООС) или (1 * БЕЛ + 1 * МАТ + 2 * НПМГ, Б) + (1 * БЗО + 1 * ХООС) : 196.75
# (1 * БЕЛ + 1 * МАТ + 2 * СПО) + (1 * БЗО + 1 * ЧЕз)                              : 196.75
# (1 * БЕЛ + 1 * МАТ + 1 * НПМГ, Х + 1 * НПМГ, Б) + (1 * БЗО + 1 * ХООС)           : 196.75
# (1 * БЕЛ + 1 * МАТ + 2 * МиФВС) + (1 * БЕЛ + 1 * Муз.)                           : 196.75
#
# Резултати от минималните балове за класиране по училища:
# за предходна година.
#
# 2277 Софийска математическа гимназия "Паисий Хилендарски" Математически (математика и информатика) - АЕ (РИЧЕ)           :  490.50
# 5011 Софийска математическа гимназия "Паисий Хилендарски" Математически (математика и физика) - НЕ (ИИЧЕ)                :  490.00
# 814 Национална природо-математическа гимназия "Академик Любомир Чакалов" Математически - АЕ М Инф                        :  488.00
# 821 Национална природо-математическа гимназия "Академик Любомир Чакалов" Математически - НЕ М Инф                        :  487.50
# 3909 Софийска математическа гимназия "Паисий Хилендарски" Математически (математика и информатика) - НЕ (ИИЧЕ)           :  487.50
# 2561 164. гимназия с преподаване на испански език "Мигел де Сервантес" Чужди езици - ИЕ интензивно, АЕ                   :  475.50
# 4922 Технологично училище "Електронни системи" към Технически Университет - София Програмиране на изкуствен интелект - АЕ, НЕ :  474.75
# 843 Национална природо-математическа гимназия "Академик Любомир Чакалов" Природни науки - АЕ ХООС БЗО                    :  472.20
# 4921 Технологично училище "Електронни системи" към Технически Университет - София Системно програмиране - АЕ, НЕ         :  471.75
# 2644 91.НЕМСКА ЕЗИКОВА ГИМНАЗИЯ Професор Константин Гълъбов" Чужди езици - НЕ интензивно, АЕ                             :  468.50
# 2127 Технологично училище "Електронни системи" към Технически Университет - София Системно програмиране - АЕ, РЕ         :  467.25
# 2564 164. гимназия с преподаване на испански език "Мигел де Сервантес" Чужди езици - ИЕ интензивно, ИтЕ                  :  467.00
# 847 Национална природо-математическа гимназия "Академик Любомир Чакалов" Икономическо развитие - АЕ ГИ М                 :  465.00
# 2132 Технологично училище "Електронни системи" към Технически Университет - София Компютърни мрежи - АЕ, РЕ              :  464.25
# 2658 73.СУ с преподаване на чужди езици "Владислав Граматик" Чужди езици - НЕ интензивно, АЕ                             :  463.50
# 2562 164. гимназия с преподаване на испански език "Мигел де Сервантес" Чужди езици - ИЕ интензивно, ФЕ                   :  461.50
# 2569 164. гимназия с преподаване на испански език "Мигел де Сервантес" Чужди езици - ИЕ интензивно, ПортЕ                :  461.00
# 719 СОФИЙСКА ГИМНАЗИЯ ПО СТРОИТЕЛСТВО, АРХИТЕКТУРА И ГЕОДЕЗИЯ "ХРИСТО БОТЕВ" Строителство и архитектура - АЕ             :  460.75
# 835 Национална природо-математическа гимназия "Академик Любомир Чакалов" Природни науки - АЕ БЗО ХООС                    :  458.72
# 830 Национална природо-математическа гимназия "Академик Любомир Чакалов" Математически - АЕ ФА М                         :  458.38
# 5128 73.СУ с преподаване на чужди езици "Владислав Граматик" Математически - НЕ интензивно, РЕ, М и ФА                   :  457.00
# 2656 73.СУ с преподаване на чужди езици "Владислав Граматик" Чужди езици - НЕ интензивно, ФЕ                             :  456.50
# 2018 Втора английска езикова гимназия "Томас Джеферсън" Чужди езици - АЕ интензивно, НЕ                                  :  453.00
# 973 СОФИЙСКА ГИМНАЗИЯ ПО СТРОИТЕЛСТВО, АРХИТЕКТУРА И ГЕОДЕЗИЯ "ХРИСТО БОТЕВ" Строителство и архитектура - НЕ             :  452.75
# 2025 Втора английска езикова гимназия "Томас Джеферсън" Чужди езици АЕ интензивно, ИЕ                                    :  452.00
# 1292 Професионална гимназия по дизайн "Елисавета Вазова" Интериорен дизайн - ИтЕ                                         :  451.00
# 2328 СОФИЙСКА ПРОФЕСИОНАЛНА ГИМНАЗИЯ по ЕЛЕКТРОНИКА "Джон Атанасов" Системно програмиране - АЕ, НЕ                       :  451.00
# 727 Първа английска езикова гимназия Чужди езици - АЕ интензивно, НЕ                                                     :  450.50
# 5127 73.СУ с преподаване на чужди езици "Владислав Граматик" Обществени науки - НЕ интензивно, РЕ, ИЦ и ГИ               :  449.00
# 3349 Първа английска езикова гимназия Предприемачески - АЕ интензивно, НЕ                                                :  448.50
# 672 Първа английска езикова гимназия Чужди езици - АЕ интензивно, ИЕ                                                     :  448.00
# 2338 СОФИЙСКА ПРОФЕСИОНАЛНА ГИМНАЗИЯ по ЕЛЕКТРОНИКА "Джон Атанасов" Приложно програмиране - АЕ, НЕ                       :  447.75
# 2034 Втора английска езикова гимназия "Томас Джеферсън" Чужди езици - АЕ интензивно, РЕ                                  :  447.50
# 4766 22 Средно езиково училище "Георги Стойков Раковски" Хуманитарен - БЕЛ/Фил, ИЕ интензивно, АЕ                        :  445.50
# 649 Първа английска езикова гимназия Чужди езици - АЕ интензивно, РЕ                                                     :  443.50
# 3998 51 СРЕДНО УЧИЛИЩЕ "ЕЛИСАВЕТА БАГРЯНА" Компютърна анимация - АЕ интензивно, ИтЕ                                      :  443.00
# 752 Първа английска езикова гимназия Чужди езици - АЕ интензивно, ФЕ                                                     :  442.00
# 3856 Професионална гимназия по дизайн "Елисавета Вазова" Интериорен дизайн - ФЕ                                          :  440.25
# 2766 31 Средно училище за чужди езици и математика "Иван Вазов" Чужди езици - ИЕ интензивно, АЕ                          :  440.00
# 2168 9 Френска езикова гимназия "Алфонс дьо Ламартин" Чужди езици - ФЕ интензивно, НЕ                                    :  440.00
# 2291 51 СРЕДНО УЧИЛИЩЕ "ЕЛИСАВЕТА БАГРЯНА" Изобразително изкуство - АЕ интензивно, ИтЕ                                   :  439.25
# 2158 9 Френска езикова гимназия "Алфонс дьо Ламартин" Чужди езици - ФЕ интензивно, АЕ                                    :  438.50
# 4140 СОФИЙСКА ПРОФЕСИОНАЛНА ГИМНАЗИЯ по ЕЛЕКТРОНИКА "Джон Атанасов" Програмиране на роботи - АЕ, НЕ                      :  437.00
# 388 35. СРЕДНО ЕЗИКОВО УЧИЛИЩЕ "ДОБРИ ВОЙНИКОВ" Чужди езици - НЕ интензивно, РЕ                                          :  436.00
# 2755 31 Средно училище за чужди езици и математика "Иван Вазов" Чужди езици - АЕ интензивно, ИЕ                          :  435.50
# 2276 51 СРЕДНО УЧИЛИЩЕ "ЕЛИСАВЕТА БАГРЯНА" Компютърна графика - АЕ интензивно, Японски език                              :  435.00
# 2163 9 Френска езикова гимназия "Алфонс дьо Ламартин" Чужди езици - ФЕ интензивно, ИЕ                                    :  435.00
# 3635 22 Средно езиково училище "Георги Стойков Раковски" Природни науки БЗО, ХООС, ИЕ - интензивно, АЕ                   :  433.50
# 762 СОФИЙСКА ГИМНАЗИЯ ПО СТРОИТЕЛСТВО, АРХИТЕКТУРА И ГЕОДЕЗИЯ "ХРИСТО БОТЕВ" Геодезия - АЕ                               :  433.50
# 4338 9 Френска езикова гимназия "Алфонс дьо Ламартин" Чужди езици - ФЕ интензивно, Латински език                         :  432.50
# 751 НАЦИОНАЛНА ТЪРГОВСКО - БАНКОВА ГИМНАЗИЯ Банково дело - АЕ интензивно, ИЕ                                             :  432.50
# 4091 Национална природо-математическа гимназия "Академик Любомир Чакалов" Природни науки - НЕ БЗО ХООС                   :  431.32
# 1637 18 Средно училище "Уилям Гладстон" Чужди езици - ЯЕ интензивно, АЕ                                                  :  431.00
# 3017 22 Средно езиково училище "Георги Стойков Раковски" Природни науки - Биол, Хим, АЕ интензивно, НЕ                   :  431.00
# 2565 22 Средно езиково училище "Георги Стойков Раковски" Хуманитарен - БЕЛ/Фил, АЕ интензивно, ИЕ                        :  431.00
# 3372 32. СРЕДНО УЧИЛИЩЕ С ИЗУЧАВАНЕ НА ЧУЖДИ ЕЗИЦИ "СВЕТИ КЛИМЕНТ ОХРИДСКИ" Природни науки - АЕ интензивно, ИЕ, БЗО и ХООС :  431.00
# 390 35. СРЕДНО ЕЗИКОВО УЧИЛИЩЕ "ДОБРИ ВОЙНИКОВ" Чужди езици - ФЕ интензивно, РЕ                                          :  430.50
# 4767 22 Средно езиково училище "Георги Стойков Раковски" Обществени науки - Ист/Фил, ИЕ интензивно, АЕ                   :  430.00
# 2759 31 Средно училище за чужди езици и математика "Иван Вазов" Чужди езици - НЕ интензивно, АЕ                          :  429.00
# 2269 133 Средно училище „Александър Сергеевич Пушкин” Чужди езици - АЕ интензивно, РЕ                                    :  428.50
# 3371 32. СРЕДНО УЧИЛИЩЕ С ИЗУЧАВАНЕ НА ЧУЖДИ ЕЗИЦИ "СВЕТИ КЛИМЕНТ ОХРИДСКИ" Софтуерни и хардуерни науки - АЕ интензивно, НЕ :  428.00
# 389 35. СРЕДНО ЕЗИКОВО УЧИЛИЩЕ "ДОБРИ ВОЙНИКОВ" Чужди езици - интензивно НЕ, РЕ                                          :  428.00
# 2771 32. СРЕДНО УЧИЛИЩЕ С ИЗУЧАВАНЕ НА ЧУЖДИ ЕЗИЦИ "СВЕТИ КЛИМЕНТ ОХРИДСКИ" Чужди езици - АЕ интензивно, НЕ              :  427.00
# 2773 32. СРЕДНО УЧИЛИЩЕ С ИЗУЧАВАНЕ НА ЧУЖДИ ЕЗИЦИ "СВЕТИ КЛИМЕНТ ОХРИДСКИ" Чужди езици - АЕ интензивно, ИЕ              :  426.50
# 2360 СОФИЙСКА ПРОФЕСИОНАЛНА ГИМНАЗИЯ по ЕЛЕКТРОНИКА "Джон Атанасов" Компютърни мрежи - АЕ, НЕ                            :  426.50
# 1906 1 Средно училище "Пенчо П. Славейков" Хуманитарни науки - ИЕ интензивно, АЕ                                         :  425.50
# 2577 22 Средно езиково училище "Георги Стойков Раковски" Обществени науки - Ист/Фил, АЕ интензивно, ИЕ                   :  424.00
# 1362 127 СРЕДНО УЧИЛИЩЕ "Иван Николаевич Денкоглу" Хуманитарни науки - ИЕ интензивно, АЕ                                 :  423.25
# 2363 СОФИЙСКА ПРОФЕСИОНАЛНА ГИМНАЗИЯ по ЕЛЕКТРОНИКА "Джон Атанасов" Компютърна техника и технологии - АЕ, НЕ             :  421.50
# 3505 35. СРЕДНО ЕЗИКОВО УЧИЛИЩЕ "ДОБРИ ВОЙНИКОВ" Природни науки - БЗО ХООС интензивно НЕ, РЕ                             :  420.50
# 1900 1 Средно училище "Пенчо П. Славейков" Обществени науки - ИЕ интензивно, АЕ                                          :  420.25
# 1358 127 СРЕДНО УЧИЛИЩЕ "Иван Николаевич Денкоглу" Хуманитарни науки - АЕ интензивно, ИЕ                                 :  419.75
# 1631 18 Средно училище "Уилям Гладстон" Чужди езици - ФЕ интензивно, ИЕ                                                  :  419.00
# 937 НАЦИОНАЛНА ТЪРГОВСКО - БАНКОВА ГИМНАЗИЯ Банково дело - НЕ интензивно, АЕ                                             :  418.00
# 802 НАЦИОНАЛНА ТЪРГОВСКО - БАНКОВА ГИМНАЗИЯ Икономическа информатика - АЕ интензивно, ИЕ                                 :  417.50
# 735 СОФИЙСКА ГИМНАЗИЯ ПО СТРОИТЕЛСТВО, АРХИТЕКТУРА И ГЕОДЕЗИЯ "ХРИСТО БОТЕВ" Водно строителство - АЕ                     :  417.25
# 3018 31 Средно училище за чужди езици и математика "Иван Вазов" Математически - АЕ интензивно, НЕ                        :  417.00
# 2775 32. СРЕДНО УЧИЛИЩЕ С ИЗУЧАВАНЕ НА ЧУЖДИ ЕЗИЦИ "СВЕТИ КЛИМЕНТ ОХРИДСКИ" Чужди езици - АЕ интензивно, ФЕ              :  416.50
# 2270 133 Средно училище „Александър Сергеевич Пушкин” Чужди езици - ФЕ интензивно, РЕ                                    :  416.00
# 788 НАЦИОНАЛНА ТЪРГОВСКО - БАНКОВА ГИМНАЗИЯ Електронна търговия - АЕ интензивно, ИЕ                                      :  415.50
# 772 СОФИЙСКА ГИМНАЗИЯ ПО СТРОИТЕЛСТВО, АРХИТЕКТУРА И ГЕОДЕЗИЯ "ХРИСТО БОТЕВ" Парково строителство и озеленяване - АЕ     :  415.50
# 359 7. СРЕДНО УЧИЛИЩЕ "СВ. СЕДМОЧИСЛЕНИЦИ" Чужди езици - АЕ интензивно, ИЕ                                               :  414.25
# 392 35. СРЕДНО ЕЗИКОВО УЧИЛИЩЕ "ДОБРИ ВОЙНИКОВ" Природни науки - интензивно ФЕ, РЕ                                       :  413.00
# 779 НАЦИОНАЛНА ТЪРГОВСКО - БАНКОВА ГИМНАЗИЯ Бизнес администрация - ИЕ интензивно, АЕ                                     :  413.00
# 897 18 Средно училище "Уилям Гладстон" Математически - АЕ интензивно, НЕ; М и Инф                                        :  412.00
# 2209 12 Средно училище " Цар Иван Асен II" Чужди езици - НЕ интензивно, АЕ/РЕ по избор                                   :  411.50
# 2777 32. СРЕДНО УЧИЛИЩЕ С ИЗУЧАВАНЕ НА ЧУЖДИ ЕЗИЦИ "СВЕТИ КЛИМЕНТ ОХРИДСКИ" Хуманитарни науки - АЕ интензивно, РЕ; БЕЛ и ИЦ :  411.50
# 748 СОФИЙСКА ГИМНАЗИЯ ПО СТРОИТЕЛСТВО, АРХИТЕКТУРА И ГЕОДЕЗИЯ "ХРИСТО БОТЕВ" Транспортно строителство - АЕ               :  411.50
# 2372 СОФИЙСКА ПРОФЕСИОНАЛНА ГИМНАЗИЯ по ЕЛЕКТРОНИКА "Джон Атанасов" Промишлена електроника - АЕ, НЕ                      :  411.00
# 1907 1 Средно училище "Пенчо П. Славейков" Природни науки - БЗО и ХООС - АЕ интензивно, ИЕ                               :  410.00
# 4855 Професионална гимназия по дизайн "Елисавета Вазова" Компютърна анимация - ИЕ                                        :  409.75
# 1294 Професионална гимназия по дизайн "Елисавета Вазова" Графичен дизайн - НЕ                                            :  409.50
# 775 НАЦИОНАЛНА ТЪРГОВСКО - БАНКОВА ГИМНАЗИЯ Застрахователно и осигурително дело - AE интензивно, ИЕ                      :  408.00
# 2754 НАЦИОНАЛНА ФИНАНСОВО-СТОПАНСКА ГИМНАЗИЯ Икономика и мениджмънт - АЕ                                                 :  408.00
# 902 18 Средно училище "Уилям Гладстон" Природни науки - НЕ интензивно, АЕ; БЗО и ХООС                                    :  407.50
# 3931 18 Средно училище "Уилям Гладстон" Чужди езици - КорЕ интензивно, АЕ                                                :  407.50
# 1522 119 Средно училище "Академик Михаил Арнаудов" Хуманитарни науки - АЕ интензивно                                     :  406.00
# 4401 127 СРЕДНО УЧИЛИЩЕ "Иван Николаевич Денкоглу" Обществени науки - ИЕ разширено, АЕ                                   :  404.25
# 933 НАЦИОНАЛНА ТЪРГОВСКО - БАНКОВА ГИМНАЗИЯ Банково дело - ФЕ интензивно, АЕ                                             :  404.00
# 2514 105. СРЕДНО УЧИЛИЩЕ "АТАНАС ДАЛЧЕВ" Чужди езици - ИтЕ интензивно, АЕ                                                :  402.00
# 3604 НАЦИОНАЛНА ФИНАНСОВО-СТОПАНСКА ГИМНАЗИЯ Икономика и мениджмънт - ИЕ                                                 :  402.00
# 4880 1 Средно училище "Пенчо П. Славейков" Маркетингови проучвания - АЕ интензивно, ИЕ                                   :  401.75
# 941 НАЦИОНАЛНА ТЪРГОВСКО - БАНКОВА ГИМНАЗИЯ Електронна търговия - РЕ интензивно, АЕ                                      :  401.50
# 1296 Професионална гимназия по дизайн "Елисавета Вазова" Рекламна графика - АЕ                                           :  400.50
# 1647 18 Средно училище "Уилям Гладстон" Чужди езици - КитЕ интензивно, АЕ                                                :  398.00
# 905 18 Средно училище "Уилям Гладстон" Природни науки - ФЕ интензивно, АЕ; БЗО и ХООС                                    :  397.00
# 2749 НАЦИОНАЛНА ФИНАНСОВО-СТОПАНСКА ГИМНАЗИЯ Икономическа информатика - АЕ                                               :  396.00
# 3148 127 СРЕДНО УЧИЛИЩЕ "Иван Николаевич Денкоглу" Предприемачески - ИЕ интензивно, АЕ                                   :  395.50
# 1364 127 СРЕДНО УЧИЛИЩЕ "Иван Николаевич Денкоглу" Природни науки - АЕ интензивно, ИЕ                                    :  395.50
# 2764 НАЦИОНАЛНА ФИНАНСОВО-СТОПАНСКА ГИМНАЗИЯ Икономика и мениджмънт - НЕ                                                 :  395.50
# 1952 134. средно училище "Димчо Дебелянов" Чужди езици - АЕ интензивно, Иврит                                            :  394.50
# 2456 138. СРЕДНО УЧИЛИЩЕ ЗА ЗАПАДНИ И ИЗТОЧНИ ЕЗИЦИ "ПРОФ. ВАСИЛ ЗЛАТАРСКИ" Чужди езици - ЯЕ интензивно, АЕ              :  394.25
# 4407 1 Средно училище "Пенчо П. Славейков" Икономическо развитие - АЕ разширено, ГИ                                      :  394.25
# 1307 30 СРЕДНО УЧИЛИЩЕ "БРАТЯ МИЛАДИНОВИ" Чужди езици - ИЕ интензивно, АЕ                                                :  394.00
# 2272 133 Средно училище „Александър Сергеевич Пушкин” Чужди езици - РЕ интензивно, АЕ                                    :  393.00
# 1365 127 СРЕДНО УЧИЛИЩЕ "Иван Николаевич Денкоглу" Природни науки - ИЕ интензивно, АЕ                                    :  392.00
# 360 7. СРЕДНО УЧИЛИЩЕ "СВ. СЕДМОЧИСЛЕНИЦИ" Икономическо развитие - АЕ интензивно, НЕ                                     :  391.50
# 1532 119 Средно училище "Академик Михаил Арнаудов" Чужди езици - РЕ интензивно                                           :  391.00
# 777 НАЦИОНАЛНА ТЪРГОВСКО - БАНКОВА ГИМНАЗИЯ Оперативно счетоводство - РЕ интензивно, АЕ                                  :  390.00
# 838 СОФИЙСКА ГИМНАЗИЯ ПО СТРОИТЕЛСТВО, АРХИТЕКТУРА И ГЕОДЕЗИЯ "ХРИСТО БОТЕВ" Брокер недвижими имоти - АЕ                 :  389.50
# 1366 127 СРЕДНО УЧИЛИЩЕ "Иван Николаевич Денкоглу" Икономическо развитие - АЕ разширено, ИЕ                              :  388.50
# 4450 7. СРЕДНО УЧИЛИЩЕ "СВ. СЕДМОЧИСЛЕНИЦИ" Природни науки - БЗО, ХООС, АЕ интензивно, НЕ                                :  388.00
# 3955 НАЦИОНАЛНА ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ПРЕЦИЗНА ТЕХНИКА И ОПТИКА "М. В. Ломоносов" Програмиране на изкуствен интелект - АЕ :  388.00
# 957 2 Средно училище "Академик Емилиян Станев " Предприемачески -АЕ интензивно, ИЕ, Предприемачество и ГИ                :  387.25
# 958 2 Средно училище "Академик Емилиян Станев " Хуманитарни науки - АЕ интензивно, ИЕ, БЕЛ и ИЦ                          :  385.00
# 4717 НАЦИОНАЛНА ФИНАНСОВО-СТОПАНСКА ГИМНАЗИЯ Икономика и мениджмънт - ФЕ                                                 :  383.50
# 3603 НАЦИОНАЛНА ФИНАНСОВО-СТОПАНСКА ГИМНАЗИЯ Икономическа информатика - НЕ                                               :  382.50
# 1546 125 СУ "Боян Пенев" с изучаване на чужди езици Хуманитарни науки - АЕ интензивно                                    :  381.75
# 4388 НАЦИОНАЛНА ФИНАНСОВО-СТОПАНСКА ГИМНАЗИЯ Оперативно счетоводство - АЕ                                                :  381.50
# 1572 Профилирана гимназия за изобразителни изкуства "Професор Николай Райнов" Компютърна графика                         :  381.25
# 916 23 Средно училище "Фредерик Жолио-Кюри" Чужди езици - ИтЕ интензивно, АЕ                                             :  381.00
# 462 Професионална гимназия по облекло "Княгиня Мария Луиза" Моден дизайн - ИтЕ, АЕ                                       :  378.75
# 4079 119 Средно училище "Академик Михаил Арнаудов" Икономическо развитие - АЕ интензивно                                 :  378.50
# 1526 119 Средно училище "Академик Михаил Арнаудов" Природни науки - АЕ интензивно                                        :  378.00
# 4814 7. СРЕДНО УЧИЛИЩЕ "СВ. СЕДМОЧИСЛЕНИЦИ" Природни науки - БЗО, ХООС, АЕ интензивно, ФЕ                                :  376.50
# 1308 30 СРЕДНО УЧИЛИЩЕ "БРАТЯ МИЛАДИНОВИ" Природни науки - ИЕ интензивно, АЕ                                             :  374.00
# 2451 138. СРЕДНО УЧИЛИЩЕ ЗА ЗАПАДНИ И ИЗТОЧНИ ЕЗИЦИ "ПРОФ. ВАСИЛ ЗЛАТАРСКИ" Чужди езици - КитЕ интензивно, АЕ            :  373.50
# 4446 12 Средно училище " Цар Иван Асен II" Предприемачески - АЕ интензивно, НЕ                                           :  373.00
# 1961 134. средно училище "Димчо Дебелянов" Природни науки - АЕ интензивно, Иврит                                         :  373.00
# 2543 105. СРЕДНО УЧИЛИЩЕ "АТАНАС ДАЛЧЕВ" Екскурзоводско обслужване - ИтЕ интензивно, АЕ                                  :  371.00
# 1354 138. СРЕДНО УЧИЛИЩЕ ЗА ЗАПАДНИ И ИЗТОЧНИ ЕЗИЦИ "ПРОФ. ВАСИЛ ЗЛАТАРСКИ" Математически - АЕ интензивно, ИЕ            :  369.50
# 738 ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ТЕЛЕКОМУНИКАЦИИ Системно програмиране - АЕ                                                 :  368.75
# 2602 30 СРЕДНО УЧИЛИЩЕ "БРАТЯ МИЛАДИНОВИ" Природни науки - АЕ интензивно, ИЕ                                             :  368.50
# 2647 121 СРЕДНО УЧИЛИЩЕ "ГЕОРГИ ИЗМИРЛИЕВ" Предприемачески - ИЕ, АЕ                                                      :  368.00
# 2215 12 Средно училище " Цар Иван Асен II" Предприемачески - ФЕ интензивно, АЕ                                           :  367.50
# 328 НАЦИОНАЛНА ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ПРЕЦИЗНА ТЕХНИКА И ОПТИКА "М. В. Ломоносов" Компютърна техника и технологии - АЕ :  367.00
# 4826 105. СРЕДНО УЧИЛИЩЕ "АТАНАС ДАЛЧЕВ" Интериорен дизайн - ИтЕ интензивно, АЕ                                          :  365.00
# 2914 3. СУ "Марин Дринов" Графичен дизайн - АЕ                                                                           :  363.25
# 4702 2 Средно училище "Академик Емилиян Станев " Програмиране на изкуствен интелект - английски интензивно, втори чужд език испански :  363.00
# 4448 121 СРЕДНО УЧИЛИЩЕ "ГЕОРГИ ИЗМИРЛИЕВ" Обществени науки - АЕ, ИЕ                                                     :  360.75
# 2159 12 Средно училище " Цар Иван Асен II" Природни науки - АЕ интензивно, НЕ                                            :  359.00
# 5038 55 СРЕДНО УЧИЛИЩЕ "ПЕТКО КАРАВЕЛОВ" Програмиране на изкуствен интелект - АЕ                                         :  359.00
# 4939 19 СРЕДНО УЧИЛИЩЕ "ЕЛИН ПЕЛИН" Предприемачески - НЕ интензивно, НорвЕ                                               :  358.00
# 1968 134. средно училище "Димчо Дебелянов" Софтуерни и хардуерни науки - АЕ интензивно, Иврит                            :  357.00
# 4565 2 Средно училище "Академик Емилиян Станев " Програмиране на изкуствен интелект - английски интензивно, втори чужд език немски :  357.00
# 743 ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ТЕЛЕКОМУНИКАЦИИ Приложно програмиране - АЕ                                                 :  356.00
# 2466 138. СРЕДНО УЧИЛИЩЕ ЗА ЗАПАДНИ И ИЗТОЧНИ ЕЗИЦИ "ПРОФ. ВАСИЛ ЗЛАТАРСКИ" Софтуерни и хардуени науки - АЕ интензивно, КорЕ :  352.50
# 4941 19 СРЕДНО УЧИЛИЩЕ "ЕЛИН ПЕЛИН" Предприемачески - АЕ интензивно, ШвЕ                                                 :  352.50
# 317 НАЦИОНАЛНА ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ПРЕЦИЗНА ТЕХНИКА И ОПТИКА "М. В. Ломоносов" Медицинска техника - НЕ             :  352.00
# 2144 55 СРЕДНО УЧИЛИЩЕ "ПЕТКО КАРАВЕЛОВ" Софтуерни и хардуерни науки - АЕ интензивно, НЕ                                 :  351.50
# 2904 203 Профилирана езикова гимназия "Свети Методий" Чужди езици - АЕ интензивно, НЕ или ИЕ                             :  349.00
# 2878 93-то Средно училище "Александър Теодоров - Балан" Обществени науки - АЕ интензивно, РЕ                             :  349.00
# 1642 18 Средно училище "Уилям Гладстон" Хуманитарни науки - АрЕ интензивно, АЕ; БЕЛ и Фил                                :  348.50
# 3676 21 СРЕДНО УЧИЛИЩЕ "ХРИСТО БОТЕВ" Предприемачески - ИЕ интензивно, АЕ                                                :  348.50
# 2408 29. Средно училище "Кузман Шапкарев" Софтуерни и хардуерни науки - АЕ интензивно                                    :  347.50
# 906 21 СРЕДНО УЧИЛИЩЕ "ХРИСТО БОТЕВ" Предприемачески - АЕ интензивно, ИЕ                                                 :  347.00
# 4940 19 СРЕДНО УЧИЛИЩЕ "ЕЛИН ПЕЛИН" Предприемачески - НЕ интензивно, ДатЕ                                                :  346.50
# 2876 93-то Средно училище "Александър Теодоров - Балан" Обществени науки - РЕ интензивно, АЕ                             :  342.50
# 1557 125 СУ "Боян Пенев" с изучаване на чужди езици Природни науки - АЕ интензивно                                       :  342.00
# 930 23 Средно училище "Фредерик Жолио-Кюри" Предприемачески - АЕ, ИтЕ                                                    :  341.50
# 472 Професионална гимназия по облекло "Княгиня Мария Луиза" Бутикови облекла - ИтЕ, АЕ                                   :  340.00
# 2637 121 СРЕДНО УЧИЛИЩЕ "ГЕОРГИ ИЗМИРЛИЕВ" Софтуерни и хардуерни науки - АЕ; ИЕ                                          :  337.50
# 939 23 Средно училище "Фредерик Жолио-Кюри" Икономическо развитие - АЕ, ИтЕ                                              :  337.50
# 4674 Професионална гимназия по облекло "Княгиня Мария Луиза" Театрален грим и перуки, АЕ, ФЕ                             :  337.00
# 4019 3. СУ "Марин Дринов" Фотография                                                                                     :  335.50
# 321 НАЦИОНАЛНА ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ПРЕЦИЗНА ТЕХНИКА И ОПТИКА "М. В. Ломоносов" Кинотехника, аудио- и видеосистеми - АЕ :  333.00
# 4009 Софийска професионална гимназия "Княгиня Евдокия" Фотография - АЕ                                                   :  333.00
# 325 НАЦИОНАЛНА ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ПРЕЦИЗНА ТЕХНИКА И ОПТИКА "М. В. Ломоносов" Лазерна и оптична техника - АЕ      :  331.00
# 1123 144 Средно училище "Народни будители" Рекламна графика - АЕ                                                         :  329.50
# 778 36 Средно училище "Максим Горки" Екскурзоводско обслужване - ИтЕ интензивно, АЕ                                      :  329.50
# 505 Професионална гимназия по облекло "Княгиня Мария Луиза" Сценичен костюм - АЕ, ФЕ                                     :  328.00
# 2910 203 Профилирана езикова гимназия "Свети Методий" Предприемачески - АЕ интензивно, ИЕ или НЕ                         :  327.50
# 324 НАЦИОНАЛНА ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ПРЕЦИЗНА ТЕХНИКА И ОПТИКА "М. В. Ломоносов" Очна оптика - НЕ                    :  327.00
# 4405 29. Средно училище "Кузман Шапкарев" Софтуерни и хардуерни науки - ИЕ разширено                                     :  326.25
# 3515 29. Средно училище "Кузман Шапкарев" Софтуерни и хардуерни науки /АЕ/                                               :  324.50
# 722 ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ТЕЛЕКОМУНИКАЦИИ Компютърни мрежи - АЕ                                                      :  324.50
# 4290 Софийска професионална гимназия "Княгиня Евдокия" Театрален, кино и телевизионен декор - АЕ                         :  322.00
# 2837 Софийска професионална гимназия "Княгиня Евдокия" Съдебна администрация - АЕ                                        :  321.00
# 1023 157 Гимназия с изучаване на чужд език "Сесар Вайехо" Чужди езици - ИЕ интензивно, АЕ                                :  318.00
# 4038 93-то Средно училище "Александър Теодоров - Балан" Софтуерни и хардуерни науки - АЕ интензивно, РЕ                  :  318.00
# 2579 81. Средно училище "Виктор Юго" Хуманитарни науки                                                                   :  313.50
# 4623 НАЦИОНАЛНО СРЕДНО УЧИЛИЩЕ "СОФИЯ" Изобразително изкуство - АЕ                                                       :  312.00
# 319 НАЦИОНАЛНА ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ПРЕЦИЗНА ТЕХНИКА И ОПТИКА "М. В. Ломоносов" Измервателна и организационна техника - АЕ :  311.50
# 749 54. СРЕДНО УЧИЛИЩЕ "Свети ИВАН РИЛСКИ" Чужди езици - АЕ интензивно, ИЕ                                               :  310.50
# 784 36 Средно училище "Максим Горки" Природни науки - АЕ интензивно, ИтЕ                                                 :  310.00
# 4439 47 Средно училище "Христо Груев Данов" Предприемачески - АЕ разширено, ИЕ                                           :  310.00
# 515 47 Средно училище "Христо Груев Данов" Предприемачески - АЕ интензивно, НЕ                                           :  307.50
# 2843 Софийска професионална гимназия "Княгиня Евдокия" Фризьорство                                                       :  307.25
# 4459 29. Средно училище "Кузман Шапкарев" Природни науки - АЕ разширено, БЗО и ХООС                                      :  307.00
# 1660 128 СРЕДНО УЧИЛИЩЕ "АЛБЕРТ АЙНЩАЙН" Софтуерни и хардуерни науки - АЕ                                                :  306.50
# 3271 203 Профилирана езикова гимназия "Свети Методий" Природни науки - АЕ интензивно, ИЕ или НЕ                          :  306.50
# 2774 33. Езикова гимназия "Света София" Чужди езици - АЕ интензивно, ФЕ или РЕ                                           :  306.00
# 491 Професионална гимназия по облекло "Княгиня Мария Луиза" Конструиране, моделиране и технология на облекло от текстил - АЕ, ФЕ :  306.00
# 2845 Софийска професионална гимназия "Княгиня Евдокия" Козметика                                                         :  306.00
# 4292 Софийска професионална гимназия "Княгиня Евдокия" Художествено осветление за театър, кино и телевизия - АЕ          :  304.00
# 2762 33. Езикова гимназия "Света София" Предприемачески - АЕ интензивно, НЕ                                              :  302.50
# 1536 44. Средно училище "Неофит Бозвели" Софтуерни и хардуерни науки - АЕ интензивно, ИЕ                                 :  302.00
# 707 ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ТЕЛЕКОМУНИКАЦИИ Електронна търговия - АЕ                                                   :  301.50
# 730 ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ТЕЛЕКОМУНИКАЦИИ Компютърна техника и технологии - АЕ                                       :  300.50
# 4283 132. Средно училище "Ваня Войнова" Пространствен дизайн                                                             :  299.75
# 2886 101. СРЕДНО УЧИЛИЩЕ "БАЧО КИРО" Икономическо развитие - АЕ интензивно, НЕ                                           :  299.50
# 2101 10 Средно училище " Теодор Траянов " Обществени науки - АЕ, ИЕ                                                      :  297.75
# 4980 203 Профилирана езикова гимназия "Свети Методий" Обществени науки - АЕ интензивно, ИЕ или НЕ                        :  296.25
# 2935 Профилирана гимназия с интензивно изучаване на румънски език "МИХАЙ ЕМИНЕСКУ" Хуманитарни науки - ИЕ интензивно, РумЕ, БЕЛ и Философия :  292.00
# 3559 144 Средно училище "Народни будители" Рекламна графика - ИЕ                                                         :  287.50
# 2797 33. Езикова гимназия "Света София" Екскурзоводско обслужване - АЕ интензивно, ИЕ                                    :  287.50
# 3215 ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ТЕЛЕКОМУНИКАЦИИ Телекомуникационни системи-АЕ                                             :  287.50
# 3381 Софийска професионална гимназия "Княгиня Евдокия" Промишлен дизайн - АЕ                                             :  285.00
# 2909 203 Профилирана езикова гимназия "Свети Методий" Природни науки - ИЕ интензивно, НЕ или АЕ                          :  283.00
# 746 ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ТЕЛЕКОМУНИКАЦИИ Икономическа информатика - АЕ                                              :  282.50
# 3873 47 Средно училище "Христо Груев Данов" Предприемачески - НЕ разширено, АЕ                                           :  282.00
# 903 96 Средно училище "Лев Николаевич Толстой" Обществени науки - АЕ интензивно, ИЕ/РЕ                                   :  281.50
# 4739 81. Средно училище "Виктор Юго" Хуманитарни науки - ЯЕ                                                              :  280.00
# 2943 118 Средно училище "Академик Людмил Стоянов" Софтуерни и хардуерни науки - АЕ интензивно, ИЕ                        :  279.00
# 1852 108 Средно училище "Никола Беловеждов" Предприемачески - АЕ разширено, РЕ                                           :  278.75
# 1670 128 СРЕДНО УЧИЛИЩЕ "АЛБЕРТ АЙНЩАЙН" Икономическо информационно осигуряване - АЕ                                     :  276.00
# 4500 ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ВИСОКИ ТЕХНОЛОГИИ "А. С. ПОПОВ" Програмиране на изкуствен интелект - АЕ интензивно; втори ЧЕ - Китайски език :  276.00
# 3382 Софийска професионална гимназия "Княгиня Евдокия" Индустриални отношения - АЕ                                       :  275.75
# 1538 44. Средно училище "Неофит Бозвели" Софтуерни и хардуерни науки - НЕ интензивно, АЕ                                 :  275.50
# 2566 81. Средно училище "Виктор Юго" Чужди езици - АЕ интензивно                                                         :  275.50
# 3251 ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ТЕКСТИЛНИ И КОЖЕНИ ИЗДЕЛИЯ Моден дизайн - АЕ                                              :  273.50
# 2767 33. Езикова гимназия "Света София" Чужди езици - АЕ интензивно, КитЕ/ГрЕ                                            :  269.50
# 2778 33. Езикова гимназия "Света София" Чужди езици - ФЕ интензивно, АЕ                                                  :  267.50
# 4462 118 Средно училище "Академик Людмил Стоянов" Софтуерни и хардуерни науки - АЕ интензивно, НЕ                        :  264.00
# 1802 39 Средно училище "Петър Динеков" Софтуерни и хардуерни науки - АЕ интензивно, РЕ/ИЕ                                :  260.00
# 2840 Софийска професионална гимназия "Княгиня Евдокия" Икономическо информационно осигуряване - АЕ                       :  257.00
# 2972 170 Средно училище "Васил Левски" Компютърна графика- АЕ                                                            :  256.50
# 1285 СОФИЙСКА ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ТУРИЗЪМ Организация на хотелиерството - АЕ                                       :  254.50
# 2367 Професионална гимназия по транспорт и енергетика "Хенри Форд" Автомобилна мехатроника (дуална) - АЕ                 :  254.00
# 2889 101. СРЕДНО УЧИЛИЩЕ "БАЧО КИРО" Софтуерни и хардуерни науки - АЕ интензивно, НЕ                                     :  253.00
# 2506 97 Средно училище "Братя Миладинови" Софтуерни и хардуерни науки - АЕ разширено                                     :  252.00
# 2769 ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ВИСОКИ ТЕХНОЛОГИИ "А. С. ПОПОВ" Системно програмиране - АЕ интензивно; - втори ЧЕ - Немски език :  252.00
# 4299 Профилирана гимназия с интензивно изучаване на румънски език "МИХАЙ ЕМИНЕСКУ" Хуманитарни науки - ИтЕ интензивно, РумЕ, БЕЛ, ИЦ :  251.50
# 2760 ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ВИСОКИ ТЕХНОЛОГИИ "А. С. ПОПОВ" Приложно програмиране - АЕ интензивно; втори ЧЕ - Немски език :  250.50
# 4284 8. Средно училище "Васил Левски" Предприемачески - АЕ разширено, РЕ                                                 :  248.00
# 1904 140. СРЕДНО УЧИЛИЩЕ "ИВАН БОГОРОВ" Графичен дизайн                                                                  :  247.50
# 1287 СОФИЙСКА ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ТУРИЗЪМ Екскурзоводско обслужване - АЕ                                           :  246.50
# 4040 54. СРЕДНО УЧИЛИЩЕ "Свети ИВАН РИЛСКИ" Икономическо развитие - АЕ интензивно, НЕ                                    :  246.25
# 2842 Софийска професионална гимназия "Княгиня Евдокия" Извършване на термални процедури - АЕ                             :  245.50
# 965 26 Средно училище "Йордан Йовков" Софтуерни и хардуерни науки - АЕ интензивно, РЕ                                    :  245.00
# 2512 97 Средно училище "Братя Миладинови" Търговия (дуална) - АЕ разширено                                               :  244.50
# 1834 137 средно училище "Ангел Кънчев" Предприемачески - АЕ интензивно, НЕ                                               :  243.50
# 2752 ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ВИСОКИ ТЕХНОЛОГИИ "А. С. ПОПОВ" Компютърни мрежи - АЕ - разширено; втори ЧЕ - Испански език :  242.75
# 3971 170 Средно училище "Васил Левски" Организация на туризма и свободното време - АЕ                                    :  241.00
# 2380 Професионална гимназия по транспорт и енергетика "Хенри Форд" Ремонт на летателни апарати - АЕ                      :  237.50
# 2934 Профилирана гимназия с интензивно изучаване на румънски език "МИХАЙ ЕМИНЕСКУ" Чужди езици - РумЕ интензивно, АЕ     :  237.50
# 5067 108 Средно училище "Никола Беловеждов" Сътрудник в малък и среден бизнес - АЕ разширено, НЕ                         :  237.25
# 3075 10 Средно училище " Теодор Траянов " Природни науки - АЕ, ИЕ                                                        :  237.00
# 5108 НАЦИОНАЛНО СРЕДНО УЧИЛИЩЕ "СОФИЯ" Природни науки - АЕ                                                               :  235.00
# 4110 39 Средно училище "Петър Динеков" Предприемачески - АЕ интензивно, РЕ/ИЕ                                            :  233.00
# 1281 СОФИЙСКА ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ТУРИЗЪМ Кетъринг - ИЕ                                                            :  232.50
# 1283 СОФИЙСКА ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ТУРИЗЪМ Производство и обслужване в заведенията за хранене и развлечения - ИтЕ   :  232.50
# 1286 СОФИЙСКА ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ТУРИЗЪМ Организация на обслужването в хотелиерството - АЕ                        :  231.00
# 758 54. СРЕДНО УЧИЛИЩЕ "Свети ИВАН РИЛСКИ" Софтуерни и хардуерни науки - АЕ интензивно, РЕ                               :  224.00
# 1312 14. средно училище "Проф. д-р Асен Златаров" Обществени науки - АЕ, РЕ                                              :  223.50
# 508 40 Средно училище "Луи Пастьор" Софтуерни и хардуерни науки - АЕ интензивно, РЕ                                      :  219.00
# 2359 95 СУ "Проф. Иван Шишманов" Бизнес администрация - РЕ интензивно; АЕ                                                :  218.75
# 3883 40 Средно училище "Луи Пастьор" Компютърна графика - АЕ, РЕ                                                         :  217.00
# 1353 88. Средно училище "Димитър Попниколов" Чужди езици - АЕ интензивно                                                 :  217.00
# 5005 ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ВИСОКИ ТЕХНОЛОГИИ "А. С. ПОПОВ" Микропроцесорна техника АЕ - разширено; втори ЧЕ - Испански език :  217.00
# 1277 СОФИЙСКА ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ТУРИЗЪМ Кетъринг - РЕ                                                            :  215.00
# 424 132. Средно училище "Ваня Войнова" Помощник-инструктор по спортно туристическа дейност - АЕ                          :  213.50
# 4827 ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ТЕКСТИЛНИ И КОЖЕНИ ИЗДЕЛИЯ Бутикови облекла                                               :  213.50
# 1284 СОФИЙСКА ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ТУРИЗЪМ Производство и обслужване в заведенията за хранене и развлечения - НЕ    :  213.00
# 2376 Професионална гимназия по транспорт и енергетика "Хенри Форд" Автотранспортна техника (дуална) - АЕ                 :  210.50
# 1838 137 средно училище "Ангел Кънчев" Хуманитарни науки - АЕ интензивно, НЕ                                             :  210.00
# 3864 ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ЕЛЕКТРОТЕХНИКА И АВТОМАТИКА Програмиране на изкуствен интелект - АЕ                       :  210.00
# 4109 96 Средно училище "Лев Николаевич Толстой" Софтуерни и хардуерни науки - АЕ интензивно, ИЕ/РЕ                       :  208.00
# 4447 39 Средно училище "Петър Динеков" Предприемачески - АЕ разширено, РЕ/ИЕ                                             :  207.00
# 2629 68. Средно училище "Академик Никола Обрешков" Софтуерни и хардуерни науки - АЕ разширено                            :  207.00
# 2756 ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ВИСОКИ ТЕХНОЛОГИИ "А. С. ПОПОВ" Телекомуникационни системи - АЕ - разширено; втори ЧЕ - Руски език :  204.75
# 1060 149 Средно училище ,,Иван Хаджийски" Софтуерни и хардуерни науки - АЕ интензивно, НЕ                                :  200.50
# 4449 96 Средно училище "Лев Николаевич Толстой" Обществени науки - ИЕ интензивно, АЕ/РЕ                                  :  197.50
# 1844 137 средно училище "Ангел Кънчев" Софтуерни и хардуерни науки - АЕ интензивно, НЕ                                   :  194.00
# 3905 131. СУ "Климент Аркадиевич Тимирязев" Бизнес администрация - АЕ, ИЕ                                                :  192.00
# 4818 95 СУ "Проф. Иван Шишманов" Екскурзоводско обслужване - АЕ интензивно, ИЕ                                           :  191.00
# 3354 95 СУ "Проф. Иван Шишманов" Предприемачески - АЕ интензивно; РЕ                                                     :  190.50
# 2783 135 средно училище "Ян Амос Коменски" Социална работа с деца и семейства в риск - АЕ                                :  181.00
# 2352 Професионална гимназия по транспорт и енергетика "Хенри Форд" Топлоенергетика (дуална) - АЕ                         :  179.00
# 3640 56. Средно училище "Професор Константин Иречек" Електронна търговия - АЕ, НЕ                                        :  172.00
# 4808 ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ТРАНСПОРТ Митническа и данъчна администрация - АЕ, НЕ                                     :  171.00
# 2200 56. Средно училище "Професор Константин Иречек" Икономическо развитие - АЕ интензивно, ИЕ                           :  169.00
# 2133 ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ЕЛЕКТРОТЕХНИКА И АВТОМАТИКА Системно програмиране - АЕ                                    :  163.00
# 909 Професионална гимназия по екология и биотехнологии "Проф. д-р Асен Златаров" Технологичен и микробиологичен контрол в химични производства - лаборант - АЕ :  161.00
# 4798 78. Средно училище "Христо Смирненски" Софтуерни и хардуерни науки - АЕ интензивно, НЕ                              :  158.00
# 2378 Професионална гимназия по транспорт и енергетика "Хенри Форд" Електрически превозни средства - АЕ                   :  157.00
# 1356 88. Средно училище "Димитър Попниколов" Туристическа анимация - АЕ интензивно                                       :  154.00
# 2364 Професионална гимназия по транспорт и енергетика "Хенри Форд" Автотранспортна техника - АЕ                          :  152.50
# 2449 131. СУ "Климент Аркадиевич Тимирязев" Търговия на едро и дребно - АЕ                                               :  150.00
# 1895 140. СРЕДНО УЧИЛИЩЕ "ИВАН БОГОРОВ" Български танци                                                                  :  148.00
# 851 Професионална гимназия по екология и биотехнологии "Проф. д-р Асен Златаров" Екология и опазване на околната среда - АЕ :  147.00
# 3671 Професионална гимназия по хранително-вкусови технологии "Проф. д-р Георги Павлов" Производство на месо, месни продукти и риба - оператор :  144.50
# 372 28 Средно училище "Алеко Константинов" Софтуерни и хардуерни науки - АЕ интензивно, ИЕ                               :  141.00
# 2177 Професионална гимназия по механоелектротехника "Н.Й.Вапцаров" Електрообзавеждане на производството - електромонтьор :  141.00
# 1911 Професионална гимназия по транспорт и енергетика "Хенри Форд" Промишлена електроника                                :  140.50
# 452 Професионална гимназия по хранително-вкусови технологии "Проф. д-р Георги Павлов" Производство и преработка на мляко и млечни продукти - АЕ :  139.50
# 1656 ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ТРАНСПОРТ Митническа и данъчна администрация - АЕ, ИЕ                                     :  139.00
# 4460 131. СУ "Климент Аркадиевич Тимирязев" Бизнес администрация - ИЕ, АЕ                                                :  138.00
# 4126 28 Средно училище "Алеко Константинов" Електронна търговия - АЕ интензивно, ИЕ                                      :  138.00
# 2459 95 СУ "Проф. Иван Шишманов" Природни науки - АЕ интензивно; РЕ                                                      :  135.00
# 2952 192. СРЕДНО УЧИЛИЩЕ "ХРИСТО БОТЕВ" Туристическа анимация                                                            :  134.50
# 2383 Професионална гимназия по транспорт и енергетика "Хенри Форд" Експлоатация на автомобилния транспорт                :  133.50
# 4004 123 Средно училищe "Стефан Стамболов" Обществени науки                                                              :  133.00
# 4454 68. Средно училище "Академик Никола Обрешков" Софтуерни и хардуерни науки - АЕ интензивно                           :  133.00
# ...
# 788 НАЦИОНАЛНА ТЪРГОВСКО - БАНКОВА ГИМНАЗИЯ, ГР.СОФИЯ Електронна търговия - АЕ интензивно, ИЕ                                     : 311.50
# 802 НАЦИОНАЛНА ТЪРГОВСКО - БАНКОВА ГИМНАЗИЯ, ГР.СОФИЯ Икономическа информатика - АЕ интензивно, ИЕ                                : 311.50
# 933 НАЦИОНАЛНА ТЪРГОВСКО - БАНКОВА ГИМНАЗИЯ, ГР.СОФИЯ Банково дело - ФЕ интензивно, АЕ                                            : 311.50
# 937 НАЦИОНАЛНА ТЪРГОВСКО - БАНКОВА ГИМНАЗИЯ, ГР.СОФИЯ Банково дело - НЕ интензивно, АЕ                                            : 311.50
# 941 НАЦИОНАЛНА ТЪРГОВСКО - БАНКОВА ГИМНАЗИЯ, ГР.СОФИЯ Електронна търговия - РЕ интензивно, АЕ                                     : 311.50
# 2807 172 Обединено училище "Христо Ботев", ГР.НОВИ ИСКЪР Производство на облекло от текстил                                       : 309.50
# 2752 ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ВИСОКИ ТЕХНОЛОГИИ "А. С. ПОПОВ", ГР.СОФИЯ Компютърни мрежи - АЕ  - разширено; втори ЧЕ - Испански език: 306.25
# 2756 ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ВИСОКИ ТЕХНОЛОГИИ "А. С. ПОПОВ", ГР.СОФИЯ Телекомуникационни системи - АЕ - разширено; втори ЧЕ - Руски език: 306.25
# 2760 ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ВИСОКИ ТЕХНОЛОГИИ "А. С. ПОПОВ", ГР.СОФИЯ Приложно програмиране - АЕ интензивно; втори ЧЕ - Немски език: 306.25
# 2769 ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ВИСОКИ ТЕХНОЛОГИИ "А. С. ПОПОВ", ГР.СОФИЯ Системно програмиране - АЕ интензивно; - втори ЧЕ - Немски език: 306.25
# 4500 ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ВИСОКИ ТЕХНОЛОГИИ "А. С. ПОПОВ", ГР.СОФИЯ Програмиране на изкуствен интелект - АЕ интензивно; втори ЧЕ - Китайски език: 306.25
# 5005 ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ВИСОКИ ТЕХНОЛОГИИ "А. С. ПОПОВ", ГР.СОФИЯ Микропроцесорна техника АЕ - разширено; втори ЧЕ - Испански език: 306.25
# 814 Национална природо-математическа  гимназия "Академик Любомир Чакалов", ГР.СОФИЯ Математически - АЕ М Инф                      : 306.25
# 821 Национална природо-математическа  гимназия "Академик Любомир Чакалов", ГР.СОФИЯ Математически - НЕ М Инф                      : 306.25
# 2277 Софийска математическа гимназия  "Паисий Хилендарски", ГР.СОФИЯ Математически (математика и информатика) - АЕ (РИЧЕ)         : 306.25
# 3909 Софийска математическа гимназия  "Паисий Хилендарски", ГР.СОФИЯ Математически (математика и информатика) - НЕ (ИИЧЕ)         : 306.25
# 4486 Софийска математическа гимназия  "Паисий Хилендарски", ГР.СОФИЯ Математически (математика и физика) - АЕ (РИЧЕ)              : 306.25
# 5011 Софийска математическа гимназия  "Паисий Хилендарски", ГР.СОФИЯ Математически (математика и физика) - НЕ (ИИЧЕ)              : 306.25
# 2459 95 СУ "Проф. Иван Шишманов", ГР.СОФИЯ Природни науки - АЕ интензивно; РЕ                                                     : 306.25
# 1895 140. СРЕДНО УЧИЛИЩЕ "ИВАН БОГОРОВ", ГР.СОФИЯ Български танци                                                                 : 303.75
# 1522 119 Средно училище "Академик Михаил Арнаудов", ГР.СОФИЯ Хуманитарни науки - АЕ интензивно                                    : 303.75
# 2837 Софийска професионална гимназия  "Княгиня Евдокия", ГР.СОФИЯ Съдебна администрация - АЕ                                      : 303.75
# 3382 Софийска професионална гимназия  "Княгиня Евдокия", ГР.СОФИЯ Индустриални отношения - АЕ                                     : 303.75
# 1852 108 Средно училище  "Никола Беловеждов", ГР.СОФИЯ Предприемачески  - АЕ разширено, РЕ                                        : 303.75
# 5067 108 Средно училище  "Никола Беловеждов", ГР.СОФИЯ Сътрудник в малък и среден бизнес - АЕ разширено, НЕ                       : 303.75
# 2379 17 СУ "Дамян Груев"  , ГР.СОФИЯ Туристическа анимация - АЕ                                                                   : 303.75
# 778 36 Средно училище  "Максим Горки", ГР.СОФИЯ Екскурзоводско обслужване - ИтЕ интензивно, АЕ                                    : 303.75
# 2910 203 Профилирана езикова гимназия "Свети Методий", ГР.СОФИЯ Предприемачески - АЕ интензивно, ИЕ или НЕ                        : 303.75
# 4980 203 Профилирана езикова гимназия "Свети Методий", ГР.СОФИЯ Обществени науки - АЕ интензивно,  ИЕ или НЕ                      : 303.75
# 1929 85 Средно училище "Отец Паисий", ГР.СОФИЯ Търговия на едро и дребно - АЕ, РЕ                                                 : 303.75
# 4471 37. Средно училище "Райна Княгиня", ГР.СОФИЯ Търговия на едро и дребно - Испански език разширено, АЕ                         : 303.75
# 2200 56. Средно училище  "Професор Константин Иречек", ГР.СОФИЯ Икономическо развитие - АЕ интензивно, ИЕ                         : 303.75
# 2512 97 Средно училище  "Братя Миладинови", ГР.СОФИЯ Търговия (дуална) - АЕ разширено                                             : 303.75
# 3037 97 Средно училище  "Братя Миладинови", ГР.СОФИЯ Търговия (дуална) - НЕ разширено                                             : 303.75
# 1838 137 средно училище  "Ангел Кънчев", ГР.СОФИЯ Хуманитарни науки - АЕ интензивно, НЕ                                           : 303.75
# 4739 81. Средно училище  "Виктор Юго", ГР.СОФИЯ Хуманитарни науки - ЯЕ                                                            : 303.75
# 1546 125 СУ "Боян Пенев" с изучаване на чужди езици, ГР.СОФИЯ Хуманитарни науки - АЕ интензивно                                   : 303.75
# 4040 54. СРЕДНО УЧИЛИЩЕ "Свети ИВАН РИЛСКИ", ГР.СОФИЯ Икономическо развитие - АЕ интензивно, НЕ                                   : 303.75
# 2886 101. СРЕДНО УЧИЛИЩЕ "БАЧО КИРО", ГР.СОФИЯ Икономическо развитие - АЕ интензивно, НЕ                                          : 303.75
# 4407 1 Средно  училище  "Пенчо П. Славейков", ГР.СОФИЯ Икономическо развитие - АЕ разширено, ГИ                                   : 303.75
# 2952 192. СРЕДНО УЧИЛИЩЕ  "ХРИСТО БОТЕВ", С.БИСТРИЦА Туристическа анимация                                                        : 303.75
# 4818 95 СУ "Проф. Иван Шишманов", ГР.СОФИЯ Екскурзоводско обслужване - АЕ интензивно, ИЕ                                          : 303.75
# 1312 14. средно училище "Проф. д-р Асен Златаров", ГР.СОФИЯ Обществени науки - АЕ, РЕ                                             : 303.75
# 2876 93-то Средно училище "Александър Теодоров - Балан", ГР.СОФИЯ Обществени науки - РЕ интензивно, АЕ                            : 303.75
# 2647 121 СРЕДНО УЧИЛИЩЕ "ГЕОРГИ ИЗМИРЛИЕВ", ГР.СОФИЯ Предприемачески - ИЕ, АЕ                                                     : 303.75
# 1642 18 Средно училище  "Уилям Гладстон", ГР.СОФИЯ Хуманитарни науки - АрЕ интензивно, АЕ; БЕЛ и Фил                              : 298.50
# 4079 119 Средно училище "Академик Михаил Арнаудов", ГР.СОФИЯ Икономическо развитие - АЕ интензивно                                : 298.50
# 2797 33. Езикова гимназия  "Света София", ГР.СОФИЯ Екскурзоводско обслужване - АЕ интензивно, ИЕ                                  : 298.50
# 887 69 Средно  училище "Димитър Маринов", ГР.СОФИЯ Икономическо развитие - АЕ, НЕ                                                 : 298.50
# 1677 ПРОФЕСИОНАЛНА ГИМНАЗИЯ  ПО ТРАНСПОРТ, ГР.СОФИЯ Автомобилна мехатроника - АЕ, НЕ                                              : 298.50
# 631 123 Средно училищe "Стефан Стамболов", ГР.СОФИЯ Логистика на товари и услуги                                                  : 298.50
# 4004 123 Средно училищe "Стефан Стамболов", ГР.СОФИЯ Обществени науки                                                             : 298.50
# 4939 19 СРЕДНО УЧИЛИЩЕ  "ЕЛИН ПЕЛИН", ГР.СОФИЯ Предприемачески - НЕ интензивно, НорвЕ                                             : 298.50
# 4940 19 СРЕДНО УЧИЛИЩЕ  "ЕЛИН ПЕЛИН", ГР.СОФИЯ Предприемачески - НЕ интензивно, ДатЕ                                              : 298.50
# 4941 19 СРЕДНО УЧИЛИЩЕ  "ЕЛИН ПЕЛИН", ГР.СОФИЯ Предприемачески - АЕ интензивно, ШвЕ                                               : 298.50
# 2956 162 Обединено училище "Отец Паисий", ГР.СОФИЯ Предприемачески                                                                : 298.50
# 1384 90 Средно училище  "Генерал Хосе де Сан Мартин", ГР.СОФИЯ Предприемачески - ИЕ, АЕ                                           : 298.50
# 2101 10 Средно училище  " Теодор Траянов ", ГР.СОФИЯ Обществени науки - АЕ, ИЕ                                                    : 298.50
# 1277 СОФИЙСКА ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ТУРИЗЪМ, ГР.СОФИЯ Кетъринг - РЕ                                                           : 298.50
# 1281 СОФИЙСКА ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ТУРИЗЪМ, ГР.СОФИЯ Кетъринг - ИЕ                                                           : 298.50
# 1283 СОФИЙСКА ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ТУРИЗЪМ, ГР.СОФИЯ Производство и обслужване в заведенията за хранене и развлечения - ИтЕ  : 298.50
# 1284 СОФИЙСКА ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ТУРИЗЪМ, ГР.СОФИЯ Производство и обслужване в заведенията за хранене и развлечения - НЕ   : 298.50
# 1285 СОФИЙСКА ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ТУРИЗЪМ, ГР.СОФИЯ Организация на хотелиерството - АЕ                                      : 298.50
# 1286 СОФИЙСКА ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ТУРИЗЪМ, ГР.СОФИЯ Организация на обслужването в хотелиерството - АЕ                       : 298.50
# 1287 СОФИЙСКА ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ТУРИЗЪМ, ГР.СОФИЯ Екскурзоводско обслужване - АЕ                                          : 298.50
# 4456 149  Средно училище ,,Иван Хаджийски", ГР.СОФИЯ Електронна търговия - АЕ интензивно, НЕ                                      : 298.50
# 2439 24 Средно училище  "П.К.Яворов", ГР.СОФИЯ Предприемачески                                                                    : 298.50
# 3354 95 СУ "Проф. Иван Шишманов", ГР.СОФИЯ Предприемачески - АЕ интензивно; РЕ                                                    : 298.50
# 3506 130. средно училище "Стефан Караджа", ГР.СОФИЯ Икономическо развитие - АЕ, НЕ                                                : 298.50
# 1530 59 ОБЕДИНЕНО УЧИЛИЩЕ  "ВАСИЛ ЛЕВСКИ", ГР.СОФИЯ Готвач                                                                        : 298.50
# 2539 94 СРЕДНО УЧИЛИЩЕ "Димитър Страшимиров", ГР.СОФИЯ Логистика на товари и услуги - куриер                                      : 298.50
# 360 7. СРЕДНО УЧИЛИЩЕ  "СВ. СЕДМОЧИСЛЕНИЦИ", ГР.СОФИЯ Икономическо развитие - АЕ интензивно, НЕ                                   : 298.50
# 4284 8. Средно училище "Васил Левски", ГР.СОФИЯ Предприемачески - АЕ разширено, РЕ                                                : 298.50
# 2565 22 Средно езиково училище  "Георги Стойков Раковски", ГР.СОФИЯ Хуманитарен - БЕЛ/Фил, АЕ интензивно, ИЕ                      : 298.50
# 2577 22 Средно езиково училище  "Георги Стойков Раковски", ГР.СОФИЯ Обществени науки  - Ист/Фил, АЕ интензивно, ИЕ                : 298.50
# 4766 22 Средно езиково училище  "Георги Стойков Раковски", ГР.СОФИЯ Хуманитарен - БЕЛ/Фил, ИЕ интензивно, АЕ                      : 298.50
# 4767 22 Средно езиково училище  "Георги Стойков Раковски", ГР.СОФИЯ Обществени науки  - Ист/Фил, ИЕ интензивно, АЕ                : 298.50
# 515 47 Средно училище "Христо Груев Данов", ГР.СОФИЯ Предприемачески - АЕ интензивно, НЕ                                          : 298.50
# 3873 47 Средно училище "Христо Груев Данов", ГР.СОФИЯ Предприемачески - НЕ разширено, АЕ                                          : 298.50
# 4439 47 Средно училище "Христо Груев Данов", ГР.СОФИЯ Предприемачески - АЕ разширено, ИЕ                                          : 298.50
# 4448 121 СРЕДНО УЧИЛИЩЕ "ГЕОРГИ ИЗМИРЛИЕВ", ГР.СОФИЯ Обществени науки - АЕ, ИЕ                                                    : 298.50
# 4507 ПРОФЕСИОНАЛНА ГИМНАЗИЯ  ПО ТЕКСТИЛНИ И КОЖЕНИ ИЗДЕЛИЯ, ГР.СОФИЯ Организация на туризма и свободното време - АЕ               : 290.75
# 344 Професионална гимназия  по туризъм "Алеко Константинов", ГР.БАНКЯ Организация на хотелиерството -  АЕ                         : 285.50
# 1648 113 СУ "САВА ФИЛАРЕТОВ", ГР.СОФИЯ Продавач-консултант /РЕ/                                                                   : 285.50
# 1676 113 СУ "САВА ФИЛАРЕТОВ", ГР.СОФИЯ Продавач-консултант /АЕ/                                                                   : 285.50
# 830 Национална природо-математическа  гимназия "Академик Любомир Чакалов", ГР.СОФИЯ Математически - АЕ ФА М                       : 262.50
# 843 Национална природо-математическа  гимназия "Академик Любомир Чакалов", ГР.СОФИЯ Природни науки - АЕ ХООС БЗО                  : 251.50
# 847 Национална природо-математическа  гимназия "Академик Любомир Чакалов", ГР.СОФИЯ Икономическо развитие - АЕ ГИ М               : 238.50
# 838 СОФИЙСКА ГИМНАЗИЯ ПО СТРОИТЕЛСТВО, АРХИТЕКТУРА И ГЕОДЕЗИЯ  "ХРИСТО БОТЕВ", ГР.СОФИЯ Брокер недвижими имоти - АЕ               : 237.50
# 1904 140. СРЕДНО УЧИЛИЩЕ "ИВАН БОГОРОВ", ГР.СОФИЯ Графичен дизайн                                                                 : 207.75
# 2291 51 СРЕДНО УЧИЛИЩЕ "ЕЛИСАВЕТА БАГРЯНА", ГР.СОФИЯ Изобразително изкуство - АЕ интензивно, ИтЕ                                  : 207.75
# 3191 132. Средно училище  "Ваня Войнова", ГР.СОФИЯ Физическо възпитание и спорт - АЕ                                              : 207.75
# 4591 162 Обединено училище "Отец Паисий", ГР.СОФИЯ Изобразително изкуство                                                         : 207.75
# 1123 144 Средно училище "Народни будители", ГР.СОФИЯ Рекламна графика - АЕ                                                        : 207.75
# 3559 144 Средно училище "Народни будители", ГР.СОФИЯ Рекламна графика - ИЕ                                                        : 207.75
# 4623 НАЦИОНАЛНО СРЕДНО УЧИЛИЩЕ "СОФИЯ", ГР.СОФИЯ Изобразително изкуство - АЕ                                                      : 207.75
# 1572 Профилирана гимназия за изобразителни изкуства  "Професор Николай Райнов", ГР.СОФИЯ Компютърна графика                       : 207.75
# 374 28 Средно училище  "Алеко Константинов", ГР.СОФИЯ Физическо възпитание и спорт - АЕ, ИЕ                                       : 196.75
# 835 Национална природо-математическа  гимназия "Академик Любомир Чакалов", ГР.СОФИЯ Природни науки - АЕ БЗО ХООС                  : 196.75
# 4091 Национална природо-математическа  гимназия "Академик Любомир Чакалов", ГР.СОФИЯ Природни науки - НЕ БЗО ХООС                 : 196.75
# 1118 144 Средно училище "Народни будители", ГР.СОФИЯ Музика - АЕ                                                                  : 196.75
# 1142 144 Средно училище "Народни будители", ГР.СОФИЯ Български танци - АЕ                                                         : 196.75
#
#
# Въвеждане на код за сравнвние на постигнатия бал на учника
# с минималнит бал за прием от предходната година. Изберете кода
# пред името на училището от списъка по-горе. Въведи ЕND за край!
# CODE / END:    2115
# Вашият резултат:
# 2115 ПРОФЕСИОНАЛНА ГИМНАЗИЯ  ПО ЕЛЕКТРОТЕХНИКА И АВТОМАТИКА, ГР.СОФИЯ Компютърни мрежи - АЕ : 311.5
#
# Минимален бал от предходха година:
# 2115 ПРОФЕСИОНАЛНА ГИМНАЗИЯ ПО ЕЛЕКТРОТЕХНИКА И АВТОМАТИКА Компютърни мрежи - АЕ : 88.0
# CODE / END:    1312
# Вашият резултат:
# 1312 14. средно училище "Проф. д-р Асен Златаров", ГР.СОФИЯ Обществени науки - АЕ, РЕ : 303.75
#
# Минимален бал от предходха година:
# 1312 14. средно училище "Проф. д-р Асен Златаров" Обществени науки - АЕ, РЕ : 223.5
# CODE / END:    2952
# Вашият резултат:
# 2952 192. СРЕДНО УЧИЛИЩЕ  "ХРИСТО БОТЕВ", С.БИСТРИЦА Туристическа анимация : 303.75
#
# Минимален бал от предходха година:
# 2952 192. СРЕДНО УЧИЛИЩЕ "ХРИСТО БОТЕВ" Туристическа анимация : 134.5
# CODE / END:    2749
# Вашият резултат:
# 2749 НАЦИОНАЛНА ФИНАНСОВО-СТОПАНСКА ГИМНАЗИЯ, ГР.СОФИЯ Икономическа информатика - АЕ : 311.5
#
# Минимален бал от предходха година:
# 2749 НАЦИОНАЛНА ФИНАНСОВО-СТОПАНСКА ГИМНАЗИЯ Икономическа информатика - АЕ : 396.0
# CODE / END:    649
# Вашият резултат:
# 649 Първа английска езикова гимназия, ГР.СОФИЯ Чужди езици - АЕ интензивно, РЕ : 311.5
#
# Минимален бал от предходха година:
# 649 Първа английска езикова гимназия Чужди езици - АЕ интензивно, РЕ : 443.5
# CODE / END:    1676
# Вашият резултат:
# 1676 113 СУ "САВА ФИЛАРЕТОВ", ГР.СОФИЯ Продавач-консултант /АЕ/ : 285.5
#
# Минимален бал от предходха година:
# 1676 113 СУ "САВА ФИЛАРЕТОВ" Продавач-консултант /АЕ/ : 48.0
# CODE / END:    END
# Вашият резултат:
#
# Минимален бал от предходха година:
# CODE / END:    END
