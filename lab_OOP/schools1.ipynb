# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
X = pd.read_excel('ball.xlsx')
dfr = pd.DataFrame(X)

# %%
dfr
# Out:
#      78. Средно училище  "Христо Смирненски", ГР.БАНКЯ   463  \
# 0    78. Средно училище  "Христо Смирненски", ГР.БАНКЯ  4798
# 1    Професионална гимназия  по туризъм "Алеко Конс...   344
# 2    Професионална гимназия  по туризъм "Алеко Конс...   358
# 3    Професионална гимназия  по туризъм "Алеко Конс...   362
# 4    2 Средно училище "Академик Емилиян Станев ", Г...   957
# ..                                                 ...   ...
# 381  НАЦИОНАЛНА ТЪРГОВСКО - БАНКОВА ГИМНАЗИЯ, ГР.СОФИЯ   788
# 382  НАЦИОНАЛНА ТЪРГОВСКО - БАНКОВА ГИМНАЗИЯ, ГР.СОФИЯ   802
# 383  НАЦИОНАЛНА ТЪРГОВСКО - БАНКОВА ГИМНАЗИЯ, ГР.СОФИЯ   933
# 384  НАЦИОНАЛНА ТЪРГОВСКО - БАНКОВА ГИМНАЗИЯ, ГР.СОФИЯ   937
# 385  НАЦИОНАЛНА ТЪРГОВСКО - БАНКОВА ГИМНАЗИЯ, ГР.СОФИЯ   941
#
#                  Извършване на термални процедури - АЕ  професионална  \
# 0      Софтуерни и хардуерни науки - АЕ интензивно, НЕ    профилирана
# 1                  Организация на хотелиерството -  АЕ  професионална
# ...

# %%
dfr.columns
# Out:
# Index(['78. Средно училище  "Христо Смирненски", ГР.БАНКЯ',
#                                                        463,
#                    'Извършване на термални процедури - АЕ',
#                                            'професионална',
#               '(2 * БЕЛ + 2 * МАТ) + (1 * БЗО + 1 * ХООС)'],
#       dtype='object')

# %%
set(dfr)
# Out:
# {'(2 * БЕЛ + 2 * МАТ) + (1 * БЗО + 1 * ХООС)',
#  463,
#  '78. Средно училище  "Христо Смирненски", ГР.БАНКЯ',
#  'Извършване на термални процедури - АЕ',
#  'професионална'}
