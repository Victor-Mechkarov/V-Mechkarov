# %%
import pandas as pd

# %%
bal = pd.read_excel('bal_2025.xlsx')

# %%
df_bal = pd.DataFrame(bal)

# %%
df_bal.columns
# Out:
# Index(['СПИСЪК НА ПАРАЛЕЛКИТЕ С ДЪРЖАВЕН ПЛАН-ПРИЕМ В VIII КЛАС ЗА УЧЕБНАТА 2025/2026 ГОДИНА В ОБЛАСТ СОФИЯ-ГРАД \nс кодове и балообразуване',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11'],
#       dtype='str')

# %%
df_bal.rename(columns={'Unnamed: 2':'School name'}, inplace=True)

# %%
df_bal.rename(columns={'Unnamed: 3':'Field code'}, inplace=True)

# %%
df_bal.rename(columns={'Unnamed: 4':'Field name'}, inplace=True)

# %%
df_bal.rename(columns={'Unnamed: 6':'Formula'}, inplace=True)

# %%
df_bal.columns
# Out:
# Index(['СПИСЪК НА ПАРАЛЕЛКИТЕ С ДЪРЖАВЕН ПЛАН-ПРИЕМ В VIII КЛАС ЗА УЧЕБНАТА 2025/2026 ГОДИНА В ОБЛАСТ СОФИЯ-ГРАД \nс кодове и балообразуване',
#        'Unnamed: 1', 'School name', 'Field code', 'Field name', 'Unnamed: 5',
#        'Formula', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11'],
#       dtype='str')

# %%
df_bal.columns
# Out:
# Index(['СПИСЪК НА ПАРАЛЕЛКИТЕ С ДЪРЖАВЕН ПЛАН-ПРИЕМ В VIII КЛАС ЗА УЧЕБНАТА 2025/2026 ГОДИНА В ОБЛАСТ СОФИЯ-ГРАД \nс кодове и балообразуване',
#        'Unnamed: 1', 'School name', 'Field code', 'Field name', 'Unnamed: 5',
#        'Formula', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11'],
#       dtype='str')

# %%
new_frame = pd.DataFrame()

# %%
new_frame['1'] = df_bal['School name']
new_frame['2'] = df_bal['Field code']
new_frame['3'] = df_bal['Field name']
new_frame['4'] = df_bal['Formula']

# %%
new_frame.rename(columns={'1':'School name'}, inplace=True)
new_frame.rename(columns={'2':'Field code'}, inplace=True)
new_frame.rename(columns={'3':'Field name'}, inplace=True)
new_frame.rename(columns={'4':'Formula'}, inplace=True)

# %%
scores = pd.read_excel("score1_2025.xlsx")

# %%
scores.columns
# Out:
# Index(['СПРАВКА\nза минималния и максималния бал по паралелки\nв РУО СОФИЯ-ГРАД\nкъм дата 21.07.2025 г.',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10'],
#       dtype='str')

# %%
scores.index
# Out:
# RangeIndex(start=0, stop=389, step=1)

# %%
new_frame.index
# Out:
# RangeIndex(start=0, stop=393, step=1)

# %%
X = set(new_frame['School name'])

# %%
X
# Out:
# {'1 Средно  училище  "Пенчо П. Славейков", ГР.СОФИЯ',
#  '10 Средно училище  " Теодор Траянов ", ГР.СОФИЯ',
#  '101. СРЕДНО УЧИЛИЩЕ "БАЧО КИРО", ГР.СОФИЯ',
#  '105. СРЕДНО УЧИЛИЩЕ  "АТАНАС ДАЛЧЕВ", ГР.СОФИЯ',
#  '108 Средно училище  "Никола Беловеждов", ГР.СОФИЯ',
#  '113 СУ "САВА ФИЛАРЕТОВ", ГР.СОФИЯ',
#  '117. СУ, ГР.СОФИЯ',
#  '118 Средно училище  "Академик Людмил Стоянов", ГР.СОФИЯ',
#  '119 Средно училище "Академик Михаил Арнаудов", ГР.СОФИЯ',
#  '12 Средно  училище " Цар Иван Асен II", ГР.СОФИЯ',
#  '121 СРЕДНО УЧИЛИЩЕ "ГЕОРГИ ИЗМИРЛИЕВ", ГР.СОФИЯ',
#  '123 Средно училищe "Стефан Стамболов", ГР.СОФИЯ',
#  '125 СУ "Боян Пенев" с изучаване на чужди езици, ГР.СОФИЯ',
#  '127 СРЕДНО УЧИЛИЩЕ "Иван Николаевич Денкоглу", ГР.СОФИЯ',
#  '128 СРЕДНО УЧИЛИЩЕ "АЛБЕРТ АЙНЩАЙН", ГР.СОФИЯ',
#  '130. средно училище "Стефан Караджа", ГР.СОФИЯ',
#  '131. СУ "Климент Аркадиевич Тимирязев", ГР.СОФИЯ',
#  '132. Средно училище  "Ваня Войнова", ГР.СОФИЯ',
# ...

# %%
set(scores['Unnamed: 2'])
# Out:
# {'1 Средно училище "Пенчо П. Славейков"',
#  '10 Средно училище " Теодор Траянов "',
#  '101. СРЕДНО УЧИЛИЩЕ "БАЧО КИРО"',
#  '105. СРЕДНО УЧИЛИЩЕ "АТАНАС ДАЛЧЕВ"',
#  '108 Средно училище "Никола Беловеждов"',
#  '113 СУ "САВА ФИЛАРЕТОВ"',
#  '117. СУ',
#  '118 Средно училище "Академик Людмил Стоянов"',
#  '119 Средно училище "Академик Михаил Арнаудов"',
#  '12 Средно училище " Цар Иван Асен II"',
#  '121 СРЕДНО УЧИЛИЩЕ "ГЕОРГИ ИЗМИРЛИЕВ"',
#  '123 Средно училищe "Стефан Стамболов"',
#  '125 СУ "Боян Пенев" с изучаване на чужди езици',
#  '127 СРЕДНО УЧИЛИЩЕ "Иван Николаевич Денкоглу"',
#  '128 СРЕДНО УЧИЛИЩЕ "АЛБЕРТ АЙНЩАЙН"',
#  '130. средно училище "Стефан Караджа"',
#  '131. СУ "Климент Аркадиевич Тимирязев"',
#  '132. Средно училище "Ваня Войнова"',
#  '133 Средно училище „Александър Сергеевич Пушкин”',
#  '134. средно училище "Димчо Дебелянов"',
#  '135 средно училище "Ян Амос Коменски"',
#  '137 средно училище "Ангел Кънчев"',
# ...

# %%
len(set(scores['Unnamed: 2']))
# Out:
# 118

# %%
len(set(df_bal['School name']))
# Out:
# 118

# %%
len(set(scores['Unnamed: 4']))
# Out:
# 312

# %%
len(set(df_bal['Field name']))
# Out:
# 323

# %%
A = set(scores['Unnamed: 4'])
B = set(df_bal['Field name'])
A.difference(B)
# Out:
# {'Име',
#  'Компютърни мрежи - АЕ - разширено; втори ЧЕ - Испански език',
#  'Маркетингови проучвания - АЕ интензивно, ИЕ',
#  'Обществени науки - АЕ интензивно, ИЕ или НЕ',
#  'Обществени науки - Ист/Фил, АЕ интензивно, ИЕ',
#  'Обществени науки - Ист/Фил, ИЕ интензивно, АЕ',
#  'Природни науки - ИЕ интензивно, НЕ или АЕ',
#  'Природни науки - интензивно ФЕ, РЕ',
#  'Хуманитарни науки - АЕ интензивно, ИЕ, БЕЛ и ИЦ',
#  'Чужди езици - АЕ интензивно, НЕ или ИЕ',
#  'Чужди езици - ФЕ интензивно, Латински език',
#  'Чужди езици - ФЕ интензивно, НЕ',
#  'Чужди езици - интензивно НЕ, РЕ'}

# %%
formula_list = list(df_bal['Formula'])

# %%
formula_string = formula_list[2:]

len(formula_string)
# Out:
# 391

# %%
while len(formula_string)>387:
    formula_string.pop()

# %%
len(formula_string)
# Out:
# 387

# %%
for simbol in formula_string:
    string = simbol.split()
    if len(string)> 15:
        continue
    print(len(string))
    print(string[0:7])
    print(string[7:])
# Out:
# 15
# ['(2', '*', 'БЕЛ', '+', '2', '*', 'МАТ)']
# ['+', '(1', '*', 'БЗО', '+', '1', '*', 'ХООС)']
# 15
# ['(2', '*', 'БЕЛ', '+', '2', '*', 'МАТ)']
# ['+', '(1', '*', 'М', '+', '1', '*', 'КМИТ)']
# 15
# ['(2', '*', 'БЕЛ', '+', '2', '*', 'МАТ)']
# ['+', '(1', '*', 'ИЦ', '+', '1', '*', 'ГИ)']
# 15
# ['(2', '*', 'БЕЛ', '+', '2', '*', 'МАТ)']
# ['+', '(1', '*', 'БЗО', '+', '1', '*', 'ХООС)']
# 15
# ['(2', '*', 'БЕЛ', '+', '2', '*', 'МАТ)']
# ['+', '(1', '*', 'БЗО', '+', '1', '*', 'ХООС)']
# 15
# ['(3', '*', 'БЕЛ', '+', '1', '*', 'МАТ)']
# ['+', '(1', '*', 'БЕЛ', '+', '1', '*', 'ЧЕз)']
# 15
# ['(3', '*', 'БЕЛ', '+', '1', '*', 'МАТ)']
# ['+', '(1', '*', 'БЕЛ', '+', '1', '*', 'ЧЕз)']
# 15
# ['(2', '*', 'БЕЛ', '+', '2', '*', 'МАТ)']
# ['+', '(1', '*', 'БЕЛ', '+', '1', '*', 'М)']
# 15
# ['(2', '*', 'БЕЛ', '+', '2', '*', 'МАТ)']
# ['+', '(1', '*', 'БЕЛ', '+', '1', '*', 'М)']
# 15
# ['(2', '*', 'БЕЛ', '+', '2', '*', 'МАТ)']
# ['+', '(1', '*', 'КМИТ', '+', '1', '*', 'ЧЕз)']
# 15
# ...

# %%
for el in string[0:7]:
    el = ( 2 * 66 + 2 * 45)

# %%
el
# Out:
# 222
