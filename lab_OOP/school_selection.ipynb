# %%
import pandas as pd

# %%
bal = pd.read_excel('bal_2025.xlsx')

# %%
df_bal = pd.DataFrame(bal)

# %%
df_bal.columns
# Out:
# Index(['СПИСЪК НА ПАРАЛЕЛКИТЕ С ДЪРЖАВЕН ПЛАН-ПРИЕМ В VIII КЛАС ЗА УЧЕБНАТА 2025/2026 ГОДИНА В ОБЛАСТ СОФИЯ-ГРАД \nс кодове и балообразуване',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11'],
#       dtype='str')

# %%
df_bal.rename(columns={'Unnamed: 2':'School name'}, inplace=True)

# %%
df_bal.rename(columns={'Unnamed: 3':'Field code'}, inplace=True)

# %%
df_bal.rename(columns={'Unnamed: 4':'Field name'}, inplace=True)

# %%
df_bal.rename(columns={'Unnamed: 6':'Formula'}, inplace=True)

# %%
df_bal
# Out:
#     СПИСЪК НА ПАРАЛЕЛКИТЕ С ДЪРЖАВЕН ПЛАН-ПРИЕМ В VIII КЛАС ЗА УЧЕБНАТА 2025/2026 ГОДИНА В ОБЛАСТ СОФИЯ-ГРАД \nс кодове и балообразуване  \
# 0                                                    №
# 1                                                  NaN
# 2                                                    1
# 3                                                    2
# 4                                                    3
# ..                                                 ...
# 388                                                387
# 389                                                NaN
# 390                                                NaN
# 391  Забележка: Балообразуването се формира, както ...
# 392  Изключение са паралелките, за които се балообр...
#
#     Unnamed: 1                                        School name  \
# 0        РАЙОН                                      Училище - име
# 1          NaN                                                NaN
# 2        БАНКЯ  78. Средно училище  "Христо Смирненски", ГР.БАНКЯ
# 3        БАНКЯ  78. Средно училище  "Христо Смирненски", ГР.БАНКЯ
# 4        БАНКЯ  Професионална гимназия  по туризъм "Алеко Конс...
# ..         ...                                                ...
# 388   ТРИАДИЦА  НАЦИОНАЛНА ТЪРГОВСКО - БАНКОВА ГИМНАЗИЯ, ГР.СОФИЯ
# 389        NaN                                                NaN
# 390        NaN                                                NaN
# 391        NaN                                                NaN
# 392        NaN                                                NaN
#
#              Field code                                       Field name  \
# 0    Код на паралелката                                  Паралелка - име
# 1                   NaN                                              NaN
# 2                   463            Извършване на термални процедури - АЕ
# 3                  4798  Софтуерни и хардуерни науки - АЕ интензивно, НЕ
# 4                   344              Организация на хотелиерството -  АЕ
# ..                  ...                                              ...
# 388                 941          Електронна търговия - РЕ интензивно, АЕ
# 389                 NaN                                              NaN
# 390                 NaN                                              NaN
# 391                 NaN                                              NaN
# 392                 NaN                                              NaN
#
#              Unnamed: 5                                     Formula  \
# 0    Вид на паралелката                              Балообразуване
# 1                   NaN                                         NaN
# 2         професионална  (2 * БЕЛ + 2 * МАТ) + (1 * БЗО + 1 * ХООС)
# 3           профилирана    (2 * БЕЛ + 2 * МАТ) + (1 * М + 1 * КМИТ)
# 4         професионална     (2 * БЕЛ + 2 * МАТ) + (1 * ИЦ + 1 * ГИ)
# ..                  ...                                         ...
# 388       професионална     (2 * БЕЛ + 2 * МАТ) + (1 * БЕЛ + 1 * М)
# 389                 NaN                                         NaN
# 390                 NaN                                         NaN
# 391                 NaN                                         NaN
# 392                 NaN                                         NaN
#
#             Unnamed: 7      Unnamed: 8      Unnamed: 9 Unnamed: 10 Unnamed: 11
# 0    Форма на обучение  Брой паралелки  Общо основание        Мъже        Жени
# 1                  NaN             NaN             NaN         NaN         NaN
# 2               дневна               1              26           0           0
# 3               дневна               1              26           0           0
# 4               дневна               1              26           0           0
# ..                 ...             ...             ...         ...         ...
# 388             дневна               1               0          13          13
# 389                NaN             410             NaN         NaN         NaN
# 390                NaN             NaN             NaN         NaN         NaN
# 391                NaN             NaN             NaN         NaN         NaN
# 392                NaN             NaN             NaN         NaN         NaN
#
# [393 rows x 12 columns]

# %%
df_bal.columns
# Out:
# Index(['СПИСЪК НА ПАРАЛЕЛКИТЕ С ДЪРЖАВЕН ПЛАН-ПРИЕМ В VIII КЛАС ЗА УЧЕБНАТА 2025/2026 ГОДИНА В ОБЛАСТ СОФИЯ-ГРАД \nс кодове и балообразуване',
#        'Unnamed: 1', 'School name', 'Field code', 'Field name', 'Unnamed: 5',
#        'Formula', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11'],
#       dtype='str')

# %%
df_bal['Formula']
# Out:
# 0                                  Балообразуване
# 1                                             NaN
# 2      (2 * БЕЛ + 2 * МАТ) + (1 * БЗО + 1 * ХООС)
# 3        (2 * БЕЛ + 2 * МАТ) + (1 * М + 1 * КМИТ)
# 4         (2 * БЕЛ + 2 * МАТ) + (1 * ИЦ + 1 * ГИ)
#                           ...
# 388       (2 * БЕЛ + 2 * МАТ) + (1 * БЕЛ + 1 * М)
# 389                                           NaN
# 390                                           NaN
# 391                                           NaN
# 392                                           NaN
# Name: Formula, Length: 393, dtype: str

# %%
df_bal.columns
# Out:
# Index(['СПИСЪК НА ПАРАЛЕЛКИТЕ С ДЪРЖАВЕН ПЛАН-ПРИЕМ В VIII КЛАС ЗА УЧЕБНАТА 2025/2026 ГОДИНА В ОБЛАСТ СОФИЯ-ГРАД \nс кодове и балообразуване',
#        'Unnamed: 1', 'School name', 'Field code', 'Field name', 'Unnamed: 5',
#        'Formula', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11'],
#       dtype='str')

# %%
new_frame = pd.DataFrame()

# %%
new_frame['1'] = df_bal['School name']
new_frame['2'] = df_bal['Field code']
new_frame['3'] = df_bal['Field name']
new_frame['4'] = df_bal['Formula']

# %%
new_frame
# Out:
#                                                      1                   2  \
# 0                                        Училище - име  Код на паралелката
# 1                                                  NaN                 NaN
# 2    78. Средно училище  "Христо Смирненски", ГР.БАНКЯ                 463
# 3    78. Средно училище  "Христо Смирненски", ГР.БАНКЯ                4798
# 4    Професионална гимназия  по туризъм "Алеко Конс...                 344
# ..                                                 ...                 ...
# 388  НАЦИОНАЛНА ТЪРГОВСКО - БАНКОВА ГИМНАЗИЯ, ГР.СОФИЯ                 941
# 389                                                NaN                 NaN
# 390                                                NaN                 NaN
# 391                                                NaN                 NaN
# 392                                                NaN                 NaN
#
#                                                    3  \
# 0                                    Паралелка - име
# 1                                                NaN
# 2              Извършване на термални процедури - АЕ
# 3    Софтуерни и хардуерни науки - АЕ интензивно, НЕ
# 4                Организация на хотелиерството -  АЕ
# ..                                               ...
# 388          Електронна търговия - РЕ интензивно, АЕ
# 389                                              NaN
# 390                                              NaN
# 391                                              NaN
# 392                                              NaN
#
#                                               4
# 0                                Балообразуване
# 1                                           NaN
# 2    (2 * БЕЛ + 2 * МАТ) + (1 * БЗО + 1 * ХООС)
# 3      (2 * БЕЛ + 2 * МАТ) + (1 * М + 1 * КМИТ)
# 4       (2 * БЕЛ + 2 * МАТ) + (1 * ИЦ + 1 * ГИ)
# ..                                          ...
# 388     (2 * БЕЛ + 2 * МАТ) + (1 * БЕЛ + 1 * М)
# 389                                         NaN
# 390                                         NaN
# 391                                         NaN
# 392                                         NaN
#
# [393 rows x 4 columns]

# %%
new_frame['4']
# Out:
# 0                                  Балообразуване
# 1                                             NaN
# 2      (2 * БЕЛ + 2 * МАТ) + (1 * БЗО + 1 * ХООС)
# 3        (2 * БЕЛ + 2 * МАТ) + (1 * М + 1 * КМИТ)
# 4         (2 * БЕЛ + 2 * МАТ) + (1 * ИЦ + 1 * ГИ)
#                           ...
# 388       (2 * БЕЛ + 2 * МАТ) + (1 * БЕЛ + 1 * М)
# 389                                           NaN
# 390                                           NaN
# 391                                           NaN
# 392                                           NaN
# Name: 4, Length: 393, dtype: str
