# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
results = np.random.randint(1, 8, 30)

# %%
results
# Out:
# array([6, 2, 5, 3, 2, 5, 1, 5, 1, 5, 7, 7, 2, 3, 7, 7, 5, 7, 2, 4, 6, 1,
#        5, 6, 7, 6, 4, 4, 4, 6], dtype=int32)

# %%
plt.plot(results, color='b')
plt.grid(False)
plt.show()
