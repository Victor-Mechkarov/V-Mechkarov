# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
results = np.random.randint(1, 8, 30)

# %%
results
# Out:
# array([3, 3, 1, 1, 4, 4, 7, 2, 4, 2, 7, 1, 4, 5, 3, 1, 7, 4, 3, 1, 5, 4,
#        6, 6, 5, 7, 4, 7, 4, 2], dtype=int32)

# %%
plt.plot(results, color='b')
plt.grid(False)
plt.xlabel("Number of experiments")
plt.ylabel("Outcomes")
plt.show()
